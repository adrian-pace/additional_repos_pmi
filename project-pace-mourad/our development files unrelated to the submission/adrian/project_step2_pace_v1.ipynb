# %%
from gensim import corpora, models
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.stem.snowball import EnglishStemmer

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from src.preprocessing import *
from src.feature_reduction import *
from src.classifiers import *
from src.plots import *
from src.CV import *

import time
import gc
import os
import gc
import psutil


import pandas as pd
import matplotlib as mpl
import sklearn as sk
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing as prepro
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
random_state=0
proc = psutil.Process(os.getpid())
mem0 = proc.memory_info().rss
print(mem0)
# Out:
# 144441344

# %% [markdown]
# PARAMETERS:

# %%
summary_weight=2
negation_distance_threshold_review=2
negation_distance_threshold_summary=4
sample_size=5000
save_location='output_figs2'

# %% [markdown]
# # Step 1

# %% [markdown]
# ## Data loading

# %%
df = pd.read_json(path_or_buf='amazon_step23.json',orient='records',lines=True)

# %%
df.head()
# Out:
#          asin helpful  overall  \
# 0  5555991584  [3, 3]        5
# 1  5555991584  [0, 0]        5
# 2  5555991584  [2, 2]        5
# 3  5555991584  [1, 1]        5
# 4  5555991584  [1, 1]        4
#
#                                           reviewText   reviewTime  \
# 0  It's hard to believe "Memory of Trees" came ou...  09 12, 2006
# 1  A clasically-styled and introverted album, Mem...   06 3, 2001
# 2  I never thought Enya would reach the sublime h...  07 14, 2003
# 3  This is the third review of an irish album I w...   05 3, 2000
# 4  Enya, despite being a successful recording art...  01 17, 2008
#
#        reviewerID          reviewerName                       summary  \
# 0  A3EBHHCZO6V2A4  Amaranth "music fan"       Enya's last great album
# 1   AZPWAXJG9OJXV             bethtexas      Enya at her most elegant
# 2  A38IRL0X2T4DPF           bob turnley               The best so far
# 3  A22IK3I6U76GX0                 Calle  Ireland produces good music.
# 4  A1AISPOIIHTHXX           Cloud "..."        4.5; music to dream to
#
#    unixReviewTime
# 0      1158019200
# 1       991526400
# 2      1058140800
# 3       957312000
# 4      1200528000

# %%
# TODO remove sampling
# Sampling to minimze computing cost
df = df.sample(sample_size,random_state=random_state)
#df.head()

# %% [markdown]
# ## Vectorizing the review text

# %%
# create a corpus class with an iterator that reads one corpus document per line without loading all into memory
from gensim import corpora
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer
import enchant

eng_dic = enchant.Dict("en_US")
tester = 1
lemmatizer = WordNetLemmatizer()
documents = np.array(df['reviewText'])

#print ('original: ',documents[tester], '\n')

# TODO use the stopwords file ? should ask fayez

negativeword_file=open('negative_words.txt')
NEGATIVEWORDS=negativeword_file.read().split()

positiveword_file=open('positive_words.txt')
POSITIVEWORDS=positiveword_file.read().split()

negationword_file=open('negation_words.txt')
NEGATIONWORDS=negationword_file.read().split()

# Not Merging both reviewText and summary because summary is more important
#documents = df[['reviewText', 'summary']].apply(lambda x: ''.join(x), axis=1)
documents=np.array(df['reviewText'])
summaries=np.array(df['summary'])

print ('original test: ',documents[tester], '\n')
print ('summary test: ',summaries[tester], '\n')
# Out:
# original test:  This is the bottom line: If you like New-Wave/Electronic music of the early eighties and you had no idea who A Flock Of Seagulls were or had no way of associating them with the way they looked or their MTV status, then you would like this album. A very undderrated band for sure, this album is awesome especially for (It's Not Me) Talking, Wishing, Nightmares, and The Traveller. I'll admit the bonus B-Sides arent the greatest but the live version of I Ran is excellent and the orginal album holds up very well. I dont think its my absolute favorite but it ties with their first album( DNA and Messages are two of my favs). The guitar and keyboard sound so good together it really creates a timeless feel, even for a New Wave band. This album speaks for itsself(and its era). Do as the album title implies...good cd. Nuff said
#
# summary test:  Still cool to listen to

# %%
#Remove special characters
documents_no_specials=remove_specials_characters(documents)
# remove stop words and tokenize
documents_no_stop= []
for document in documents_no_specials:
    new_text=[]
    for word in document.lower().split():
        if word not in STOPWORDS:
            new_text.append(word)
    documents_no_stop.append(new_text)
    
#print ('tokenize and remove stop words: ',documents_no_stop[tester], '\n')

#Remove special characters
summaries_no_specials=remove_specials_characters(summaries)
# remove stop words and tokenize
summaries_no_stop= []
for document in summaries_no_specials:
    new_text=[]
    for word in document.lower().split():
        if word not in STOPWORDS:
            new_text.append(word)
    summaries_no_stop.append(new_text)
    
#print ('tokenize and remove stop words: ',documents_no_stop[tester], '\n')

# %%
documents_no_stop_no_numeric = remove_numerical(documents_no_stop)
summaries_no_stop_no_numeric = remove_numerical(summaries_no_stop)
#print ('remove numerics: ',documents_no_stop_no_numeric[tester], '\n')

# %%
# lemmattizing tokens (better than stemming by taking word context into account)

documents_no_stop_no_numeric_lemmatize = [[lemmatizer.lemmatize(token) for token in text] 
                                                    for text in documents_no_stop_no_numeric]
summaries_no_stop_no_numeric_lemmatize = [[lemmatizer.lemmatize(token) for token in text] 
                                                    for text in summaries_no_stop_no_numeric]

#print ('lemmatize: ',documents_no_stop_no_numeric_lemmatize[tester], '\n')

# %%
# remove non-english words

documents_no_stop_no_numeric_lemmatize_english = [[token for token in text if (eng_dic.check(token)) ] 
                                                            for text in documents_no_stop_no_numeric_lemmatize]

print ('no english: ',documents_no_stop_no_numeric_lemmatize_english[tester], '\n')

summaries_no_stop_no_numeric_lemmatize_english = [[token for token in text if (eng_dic.check(token)) ] 
                                                            for text in summaries_no_stop_no_numeric_lemmatize]

print ('no english: ',summaries_no_stop_no_numeric_lemmatize_english[tester], '\n')
# Out:
# no english:  ['line', 'like', 'new', 'wave', 'electronic', 'music', 'early', 'eighty', 'idea', 'flock', 'seagull', 'way', 'associating', 'way', 'looked', 'status', 'like', 'album', 'band', 'sure', 'album', 'awesome', 'especially', 'talking', 'wishing', 'nightmare', 'ill', 'admit', 'bonus', 'b', 'side', 'greatest', 'live', 'version', 'ran', 'excellent', 'album', 'hold', 'think', 'absolute', 'favorite', 'tie', 'album', 'message', 'guitar', 'keyboard', 'sound', 'good', 'creates', 'timeless', 'feel', 'new', 'wave', 'band', 'album', 'speaks', 'era', 'album', 'title', 'implies', 'good', 'said']
#
# no english:  ['cool', 'listen']

# %%
# create ready corpus

df['reviewCleaned'] = [" ".join(doc) for doc in documents_no_stop_no_numeric_lemmatize_english] 
df['summaryCleaned'] = [" ".join(doc) for doc in summaries_no_stop_no_numeric_lemmatize_english] 

#df['reviewCleaned']

# %%
def keepAdjectives(documents,NEGATIONWORDS, POSITIVEWORDS, NEGATIVEWORDS,negation_distance_threshold):
    
    document_neg_pos = []
    document_neg_count = np.zeros(df.shape[0])
    document_pos_count = np.zeros(df.shape[0])

    for idx,row in enumerate(documents):
        review = []
        new_word = ""
        negation_distance=0
        
        for word in row.split(" "):
            if len(new_word) != 1:
                negation_distance+=1
                if negation_distance>negation_distance_threshold:
                    new_word=""
            if word in NEGATIONWORDS:
                new_word = word
                negation_distance=0
            elif word in POSITIVEWORDS:
                if len(new_word)==0:
                    review.append(word)
                    document_pos_count[idx]+=1
                else:
                    #print(idx)
                    document_neg_count[idx]+=1
                    new_word = new_word + word
                    review.append(new_word)
                    new_word = ""
            elif word in NEGATIVEWORDS:
                if len(new_word)==0:
                    review.append(word)
                    document_neg_count[idx]+=1
                else:
                    #print(idx)
                    document_pos_count[idx]+=1
                    new_word = new_word + word
                    review.append(new_word)
                    new_word = ""
        document_neg_pos.append(review)
    return document_neg_pos, document_pos_count, document_neg_count

# Not sure if ratio of counts is relevent since someone who like average
# the product a juste write 'good...' would get an extremely high ratio
documents_neg_pos, documents_pos_count, documents_neg_count = keepAdjectives(
    df['reviewCleaned'],NEGATIONWORDS,POSITIVEWORDS,NEGATIVEWORDS,negation_distance_threshold_review)
print("Kept only adjectives pairs:",documents_neg_pos[tester], 
      '\nPositive count=',documents_pos_count[tester],'Negative counts=',documents_neg_count[tester])

summaries_neg_pos, summaries_pos_count, summaries_neg_count = keepAdjectives(
    df['summaryCleaned'],NEGATIONWORDS,POSITIVEWORDS,NEGATIVEWORDS,negation_distance_threshold_summary)
print("Kept only adjectives pairs:",summaries_neg_pos[tester], 
      '\nPositive count=',summaries_pos_count[tester],'Negative counts=',summaries_neg_count[tester])
# Out:
# Kept only adjectives pairs: ['like', 'like', 'awesome', 'nightmare', 'bonus', 'greatest', 'excellent', 'favorite', 'good', 'good']
# Positive count= 9.0 Negative counts= 1.0
# Kept only adjectives pairs: ['cool']
# Positive count= 1.0 Negative counts= 0.0

# %%
print ('original text: ',documents[373], '\n')
print ('no english: ',documents_no_stop_no_numeric_lemmatize_english[373], '\n')
print("Kept only adjectives pairs:",documents_neg_pos[373], 
      '\nPositive count=',documents_pos_count[373],'Negative counts=',documents_neg_count[373])
print ('original text: ',summaries[373], '\n')
print ('no english: ',summaries_no_stop_no_numeric_lemmatize_english[373], '\n')
print("Kept only adjectives pairs:",summaries_neg_pos[373],
      '\nPositive count=',summaries_pos_count[373],'Negative counts=',summaries_neg_count[373])
# Out:
# original text:  Busta Rhymes in 98 came out with what i felt was the most  creative album of his career  ELE is back with another slamming CD  while Anarchy may not be as innovative as  ELE was this CD still  is blazing..  Busta's  flows  are tight as ever.. Production is on  point with  long time producer DJ.  Scratch who has been down since Busta's solo debut The Coming.. DJ Scratch  deliver such  bangers on  Busta's new CD  Salute Da Goods,  We Comin  Through which  he takes a page out of Swizz Beatz book of beats .. This  track sounds like something Swizz Beatz would have done  ..  One of the  best cuts on the album  .. Producer Jay Dee brings a raw banging sound to  tracks  Enjoy Da Ride, Live It Up,  Show Me What You Got For Me all these  tracks mention are hot .. The best cut on the album clearly is The Heist  featuring Raekwon, Ghostface Killa, Flip Mode's newest member Roc-Marciano  this track is worth the price of CD alone  the song depict  jewerly robbery  gone bad.. Other noteworthy cuts;  Make Noise featuring Lenny Kravitz,  Why  We Die featuring DMX &amp;Jay-Z, Get Out,  How Much We Grew this song  depict the beginning of Busta Rhymes all the people that have been down  with him from the beginning people that made it happen for him ..  This CD  is hot and belongs in all true hip headz collection  Pick it up you wont  regret it ..
#
# no english:  ['rhyme', 'came', 'felt', 'creative', 'album', 'career', 'slamming', 'anarchy', 'innovative', 'blazing', 'flow', 'tight', 'production', 'point', 'long', 'time', 'producer', 'scratch', 'solo', 'debut', 'coming', 'scratch', 'deliver', 'banger', 'new', 'salute', 'good', 'take', 'page', 'book', 'beat', 'track', 'sound', 'like', 'best', 'cut', 'album', 'producer', 'jay', 'brings', 'raw', 'banging', 'sound', 'track', 'enjoy', 'ride', 'live', 'got', 'track', 'mention', 'hot', 'best', 'cut', 'album', 'clearly', 'heist', 'featuring', 'flip', 'mode', 'newest', 'member', 'track', 'worth', 'price', 'song', 'depict', 'robbery', 'gone', 'bad', 'noteworthy', 'cut', 'noise', 'featuring', 'die', 'featuring', 'jay', 'z', 'grew', 'song', 'depict', 'beginning', 'rhyme', 'people', 'beginning', 'people', 'happen', 'hot', 'belongs', 'true', 'hip', 'collection', 'pick', 'wont', 'regret']
#
# Kept only adjectives pairs: ['creative', 'anarchy', 'innovative', 'scratch', 'scratch', 'salute', 'good', 'like', 'best', 'enjoy', 'hot', 'best', 'clearly', 'worth', 'bad', 'noteworthy', 'noise', 'die', 'hot', 'wontregret']
# Positive count= 14.0 Negative counts= 6.0
# original text:  BUSTA STRIKES AGAIN
#
# no english:  ['strike']
#
# Kept only adjectives pairs: ['strike']
# Positive count= 0.0 Negative counts= 1.0

# %%
df["reviewWorded"] = [" ".join(doc) for doc in documents_neg_pos]
df["summaryWorded"] = [" ".join(doc) for doc in summaries_neg_pos]
df['review_count_pos'] = documents_pos_count
df['review_count_neg'] = documents_neg_count
df['summary_count_pos'] = summaries_pos_count
df['summary_count_neg'] = summaries_neg_count
# Not sure if ratio of counts is relevent since someone who like average
# the product a juste write 'good...' would get an extremely high ratio.
# However, the difference between the two could be interesting
df['review_count_difference']=df['review_count_pos']-df['review_count_neg']
df['summary_count_difference']=df['summary_count_pos']-df['summary_count_neg']
df['total_count_difference']=df['review_count_difference']+summary_weight*df['summary_count_difference']
df.head()
# Out:
#              asin  helpful  overall  \
# 18091  B000002NBY   [0, 0]        5
# 47316  B0002ZDW80   [3, 3]        4
# 44199  B0000DD79B  [2, 87]        1
# 44398  B0000DFZZA   [9, 9]        4
# 18616  B000002O6A   [0, 2]        4
#
#                                               reviewText   reviewTime  \
# 18091  I have given other albums five stars, but "Gra...   08 3, 2002
# 47316  This is the bottom line: If you like New-Wave/...   11 1, 2004
# 44199  Great, just what we need.  A 2-album disc set ...  10 30, 2003
# 44398  Upon hearing ''I'm Like A Bird'' for the very ...  03 21, 2004
# 18616  I have known about "Lizard" since its release ...  08 23, 2007
#
#            reviewerID                           reviewerName  \
# 18091  A2VBI34EIGLG9C                                  Emily
# 47316   A9IZ4H60VZMMT                           Herbert West
# 44199  A1NVEW628JUS2Y                          Da Peace Dogg
# 44398  A1SJ1GPWF60GU0                                MJ "MJ"
# 18616  A21VBTSS7MSSMO  John Marshall Lancaster "Buffett fan"
#
#                                     summary  unixReviewTime  \
# 18091  Amazing Album--TRUELY Merits 5 Stars      1028332800
# 47316               Still cool to listen to      1099267200
# 44199       Hippies are gonna love this one      1067472000
# 44398          No One Trick Pony In My Book      1079827200
# 18616                             Good Disc      1187827200
#
#                                            reviewCleaned  \
# 18091  given album star simply exceeds rating slightl...
# 47316  line like new wave electronic music early eigh...
# 44199  great need album disc set feature overrated in...
# 44398  hearing like bird time instantly took dislike ...
# 18616  known lizard release adding collection best wa...
#
#                  summaryCleaned  \
# 18091  amazing album merit star
# 47316               cool listen
# 44199                gonna love
# 44398           trick pony book
# 18616                 good disc
#
#                                             reviewWorded  summaryWorded  \
# 18091  exceeds miraculous powerful distinctive master...  amazing merit
# 47316  like like awesome nightmare bonus greatest exc...           cool
# 44199  great overrated annoying break jealous boring ...           love
# 44398  like instantly dislike simplistic darling whoa...          trick
# 18616  best great pleasantly pleased worth unjustly like           good
#
#        review_count_pos  review_count_neg  summary_count_pos  \
# 18091              79.0              14.0                2.0
# 47316               9.0               1.0                1.0
# 44199               5.0              11.0                1.0
# 44398              40.0              13.0                0.0
# 18616               6.0               1.0                1.0
#
#        summary_count_neg  review_count_difference  summary_count_difference  \
# 18091                0.0                     65.0                       2.0
# 47316                0.0                      8.0                       1.0
# 44199                0.0                     -6.0                       1.0
# 44398                1.0                     27.0                      -1.0
# 18616                0.0                      5.0                       1.0
#
#        total_count_difference
# 18091                    69.0
# 47316                    10.0
# 44199                    -4.0
# 44398                    25.0
# 18616                     7.0

# %%
# REMOVE DF_min and df _ max
vectorizer = CountVectorizer()
# vectorizer = TfidfVectorizer() We don't need to reduce the importance of words that appear often since they are already filtered

# fit vectorizer, carry out vectorization and display results
vectorizer.fit(df[['reviewWorded', 'summaryWorded']].apply(lambda x: ''.join(x), axis=1))   # TODO join with df[['reviewText', 'summary']].apply(lambda x: ''.join(x), axis=1)
documents_vec = vectorizer.transform(df['reviewWorded'])
summaries_vec = vectorizer.transform(df['summaryWorded'])
summaries_vec*=summary_weight
documents_vec+=summaries_vec
#print(documents_vec) # sparse matrix representation

# %%
print(documents_vec)
# Out:
#   (0, 3356)	1.72574755945
#   (0, 58)	0.0951873896963
#   (0, 109)	1.06352170397
#   (0, 118)	0.0881016758555
#   (0, 230)	0.191809755792
#   (0, 310)	0.0982782265349
#   (0, 328)	0.0686069188496
#   (0, 347)	0.0894600801219
#   (0, 626)	0.0612566546225
#   (0, 637)	0.083030592699
#   (0, 700)	0.0540261172294
#   (0, 711)	0.190374779393
#   (0, 819)	0.0644339401528
#   (0, 825)	0.0713802634617
#   (0, 892)	0.119572613599
#   (0, 906)	0.109379474649
#   (0, 953)	0.0889931967493
#   (0, 1005)	0.0691928764843
#   (0, 1081)	0.0597981493986
#   (0, 1367)	0.258252156827
#   (0, 1652)	0.111343132696
#   (0, 1686)	0.079996293504
#   (0, 1694)	0.116291155796
#   (0, 1703)	0.123803148498
#   (0, 1717)	0.102239795276
#   :	:
#   (4995, 672)	0.354445232267
#   (4995, 1682)	0.292727042219
#   (4995, 2067)	0.543350105522
#   (4995, 2152)	0.100053359091
#   (4995, 2563)	0.199741068613
#   (4995, 3106)	0.278078287512
#   (4995, 4058)	0.208817973679
#   (4995, 4996)	0.248168674007
#   (4995, 5087)	0.295418786647
#   (4996, 2252)	0.384666677816
#   (4996, 2412)	0.867320147705
#   (4996, 3512)	0.315891292003
#   (4997, 4454)	0.793403001165
#   (4997, 4934)	0.608696704232
#   (4998, 3004)	0.139031649815
#   (4998, 3135)	0.370512518978
#   (4998, 3150)	0.361649827275
#   (4998, 4640)	0.844156428668
#   (4999, 1012)	2.0
#   (4999, 1606)	0.453051978217
#   (4999, 1822)	0.225367013927
#   (4999, 1877)	0.339717102456
#   (4999, 2152)	0.160660050987
#   (4999, 3621)	0.585190251884
#   (4999, 4317)	0.510182929432

# %%
# Cleaning memory

proc = psutil.Process(os.getpid())
mem1 = proc.memory_info().rss
del lemmatizer, document,documents,documents_no_specials,documents_no_stop,documents_no_stop_no_numeric
del documents_no_stop_no_numeric_lemmatize,documents_no_stop_no_numeric_lemmatize_english, eng_dic
del  summaries,summaries_no_specials,summaries_no_stop,summaries_no_stop_no_numeric
del summaries_no_stop_no_numeric_lemmatize,summaries_no_stop_no_numeric_lemmatize_english
mem2 = proc.memory_info().rss
gc.collect()
mem3 = proc.memory_info().rss
pd = lambda x2, x1: 100.0 * (x2 - x1) / mem0
print ("Allocation: %0.2f%%" % pd(mem1, mem0))
print ("Unreference: %0.2f%%" % pd(mem2, mem1))
print ("Collect: %0.2f%%" % pd(mem3, mem2))
print ("Overall: %0.2f%%" % pd(mem3, mem0))
# Out:
# Allocation: 225.33%
# Unreference: -3.23%
# Collect: 0.00%
# Overall: 222.11%

# %% [markdown]
# ## Category Prediction

# %% [markdown]
# ### Pre-Processing

# %% [markdown]
# X is the review word vector. y are the corresponding categories.
#
# The data is Min/max scaled into [0;1]. It isn't standartize because we want positive values. One could try a normalization (l1 or l2 for example)
#
# We split the data into a train and test set.
#
# tf/idf is not relevant since words that appear often might suggest a category (such as 'book')

# %%
from scipy.sparse import hstack,csr_matrix
y=np.where(df['overall']==5,1,0)
print(y.shape)

ranks=np.unique(y)
X_scaled=preprocessing.normalize(documents_vec,norm='max', copy=False)
#X_scaled=documents_vec
#X=df[['total_count_difference','review_count_pos','review_count_neg','summary_count_pos','summary_count_neg']]

proc.memory_info().rss

from scipy.sparse import hstack,csr_matrix
count_diff = csr_matrix(df['total_count_difference']).T
count_pos_rev = csr_matrix(df['review_count_pos']).T
count_neg_rev = csr_matrix(df['review_count_neg']).T
count_pos_sum = csr_matrix(df['summary_count_pos']).T
count_neg_sum = csr_matrix(df['summary_count_neg']).T

hstack([count_neg_sum,X_scaled])
X=hstack([hstack([hstack([count_diff,count_pos_rev]),hstack([count_neg_rev,count_pos_sum])])
         ,hstack([count_neg_sum,X_scaled])])

#X=X_scaled # just words
print(X.shape)
# Out:
# (5000,)
# (5000, 5700)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

# %%
proc.memory_info().rss
# Out:
# 465256448

# %%
# Numpy arrays
#X_train=np.array(X_train)
#X_test=np.array(X_test)
#y_train=np.array(y_train)
#y_test=np.array(y_test)

# %% [markdown]
# ### Trying Feature selection

# %% [markdown]
# #### select k best

# %%
from sklearn.feature_selection import SelectKBest
parameter_search_feature_selection(LogisticRegression(C=0.74438, n_jobs=-1),SelectKBest(),'k',np.logspace(2,3.7,10).astype(int),
                                   X_train,y_train,random_state=random_state,save_fig=save_location+'/slt_k_best.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-46d8a1199145> in <module>()
#       1 from sklearn.feature_selection import SelectKBest
#       2 parameter_search_feature_selection(LogisticRegression(C=0.74438, n_jobs=-1),SelectKBest(),'k',np.logspace(2,3.7,10).astype(int),
# ----> 3                                    X_train,y_train,random_state=random_state,save_fig=save_location+'/slt_k_best.png')
#
# TypeError: parameter_search_feature_selection() got an unexpected keyword argument 'save_fig'

# %% [markdown]
# #### Latent Semantic Indexing

# %%
X_train_concepts,X_test_concepts = LSI_concepts(X_train,X_test,num_lsi_topics = 100,words=vectorizer.get_feature_names())

# %%
start = time.time()

y_pred=cosine_pred(X_train_concepts,X_test_concepts,y_train,categories)
print("accuracy:",accuracy_score(y_test,y_pred))

end=time.time()
print("Execution time : {} seconds".format(end-start))
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.417
# Execution time : 15.908146142959595 seconds

# %%
start=time.time()

accuracy=[]
num_lsi_topics_array = [25,30,35,40,50,60,70,80,90,100,200,300,400,500,600,700,800,900,1000,2000,3000,4000,5000,6000,7000]
# Check various C
for num_lsi_topics in num_lsi_topics_array:
    print(num_lsi_topics)
    # fit classifier 
    X_train_concepts,X_test_concepts = LSI_concepts(X_train,X_test,num_lsi_topics,words=vectorizer.get_feature_names())
    
    y_pred=cosine_pred(X_train_concepts,X_test_concepts,y_train, categories)
    print("accuracy:",accuracy_score(y_test,y_pred))
    accuracy.append(accuracy_score(y_test,y_pred))

# Plot
plt.plot(num_lsi_topics_array,accuracy)
plt.ylabel("accuracy Score")
plt.xlabel("number of topics values")
plt.show()

end=time.time()
print("Execution time : {} seconds".format(end-start))
best_c=num_lsi_topics_array[np.argmax(accuracy)]
print("best num_lsi_topics=",best_c,"with accuracy score:", np.max(accuracy))
# Out:
# 25
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.297
# 30
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.298
# 35
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.31
# 40
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.323
# 50
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.345
# 60
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.376
# 70
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.385
# 80
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.393
# 90
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.424
# 100
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.424
# 200
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.465
# 300
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.477
# 400
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.489
# 500
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.494
# 600
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.501
# 700
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.502
# 800
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.502
# 900
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.507
# 1000
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.504
# 2000
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.513
# 3000
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.514
# 4000
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.514
# 5000
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.514
# 6000
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.514
# 7000
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# accuracy: 0.514
# Execution time : 3555.529062271118 seconds
# best num_lsi_topics= 3000 with accuracy score: 0.514

# %% [markdown]
# #### Latent Dirichlet Allocation LDA

# %%
# USE LSI number of concepts and then tune update every and passes
start = time.time()
X_train_concepts,X_test_concepts = LDA_concepts(X_train,X_test,num_lda_topics = 100,words=vectorizer.get_feature_names())
y_pred=cosine_pred(X_train_concepts,X_test_concepts,y_train,categories)
print("accuracy:",accuracy_score(y_test,y_pred))

end=time.time()
print("Execution time : {} seconds".format(end-start))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-d65a4f5df579> in <module>()
#       1 # USE LSI number of concepts and then tune update every and passes
#       2 start = time.time()
# ----> 3 X_train_concepts,X_test_concepts = LDA_concepts(X_train,X_test,num_lda_topics = 100,words=vectorizer.get_feature_names())
#       4 y_pred=cosine_pred(X_train_concepts,X_test_concepts,y_train,categories)
#       5 print("accuracy:",accuracy_score(y_test,y_pred))
#
# /home/pace/Documents/data_science/project-pace-mourad/adrian/feature_reduction.py in LDA_concepts(X_train, X_test, num_lda_topics, words, update_every, passes)
#      44     corpus = matutils.Dense2Corpus(X_train, documents_columns=False)
#      45     lsi_transformer = lda_transformer = models.LdaModel(corpus, id2word=dictionary, num_topics=num_lda_topics,
# ---> 46                                                         update_every=update_every, passes=passes, alpha='auto')
#      47     corpus_lda = lda_transformer[corpus]
#      48     X_train_concepts = matutils.corpus2dense(corpus_lda, num_terms=num_lda_topics).T
#
# /home/pace/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics)
#     327         self.state = LdaState(self.eta, (self.num_topics, self.num_terms))
#     328         self.state.sstats = self.random_state.gamma(100., 1. / 100., (self.num_topics, self.num_terms))
# --> 329         self.expElogbeta = np.exp(dirichlet_expectation(self.state.sstats))
#     330
#     331         # if a training corpus was provided, start estimating the model right away
#
# /home/pace/anaconda3/lib/python3.6/site-packages/gensim/matutils.py in dirichlet_expectation(alpha)
#     538         result = psi(alpha) - psi(np.sum(alpha))
#     539     else:
# --> 540         result = psi(alpha) - psi(np.sum(alpha, 1))[:, np.newaxis]
#     541     return result.astype(alpha.dtype)  # keep the same precision as input
#     542
#
# KeyboardInterrupt:

# %%
start=time.time()

accuracy=[]
num_lda_topics_array = [25,30,35,40,50,60,70,80,90,100,200,300,400,500,600,700,800,900,1000,2000,3000,4000,5000,6000,7000]
# Check various C
for num_lda_topics in num_lda_topics_array:
    print(num_lda_topics)
    # fit classifier 
    X_train_concepts,X_test_concepts = LDA_concepts(X_train,X_test,num_lsi_topics,words=vectorizer.get_feature_names())
    
    y_pred=cosine_pred(X_train_concepts,X_test_concepts,y_train, categories)
    print("accuracy:",accuracy_score(y_test,y_pred))
    accuracy.append(accuracy_score(y_test,y_pred))

# Plot
plt.plot(num_lda_topics_array,accuracy)
plt.ylabel("accuracy Score")
plt.xlabel("Number of topics values")
plt.show()

end=time.time()
print("Execution time : {} seconds".format(end-start))
best_c=num_lsi_topics_array[np.argmax(accuracy)]
print("best num_lsi_topics=",best_c,"with accuracy score:", np.max(accuracy))

# %% [markdown]
# ### Classifying

# %% [markdown]
# #### dummy classifier

# %% [markdown]
# Baseline model: Assign the categories randomly.

# %%
from sklearn.dummy import DummyClassifier
dmy=DummyClassifier(random_state=random_state)
dmy.fit(X_train,y_train)
y_pred=dmy.predict(X_test)
print("accuracy:",accuracy_score(y_test,y_pred))
# Out:
# accuracy: 0.516

# %% [markdown]
# #### Cosine similarity

# %% [markdown]
# For each category  we regroup the documents belonging to this category together. Then for each element we want to predict, we check how similar it is compared to each group (cosine similarity). The most similar group gives the category to the element.

# %%
from sklearn.model_selection import cross_val_score


start= time.time()
cosine_classifier=Cosine_sim(categories)
print("Mean CV valdiation score:",np.mean(cross_val_score(
    cosine_classifier,X_train,y_train,scoring='accuracy',cv=5,verbose=2,n_jobs=-1)))
end=time.time()
print("Execution time : {} seconds".format(end-start))
# Out:
# [CV]  ................................................................
# [CV]  ................................................................
# 0
# [CV]  ................................................................
# 0
# [CV]  ................................................................
# 0
# [CV]  ................................................................
# 0
# 0
# 100
# 100
# 100
# 100
# 100
# 200
# 200
# 200
# 200
# 200
# 300
# 300
# 300
# 300
# 300
# 400
# 400
# 400
# 400
# 400
# 500
# 500
# 500
# 500
# 500
# 600
# 600
# 600
# 600
# 600
# 700
# 700
# 700
# 700
# 700
# [CV] ................................................. , total=14.7min
# [CV] ................................................. , total=14.9min
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 14.9min remaining: 22.3min
# [CV] ................................................. , total=14.9min
# [CV] ................................................. , total=15.3min
# [CV] ................................................. , total=15.3min
# Mean CV valdiation score: 0.5125
# Execution time : 920.8456282615662 seconds
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 15.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 15.3min finished

# %% [markdown]
# #### Decision tree

# %% [markdown]
# Try various maximum depths for a classic decision tree classifier

# %%
parameter_search(DecisionTreeClassifier(random_state=random_state),
                {'max_depth':range(1,400,10)},
                X_train,
                y_train,save_file=save_location+'/decision tree.png')
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] max_depth=1 .....................................................
# [CV] max_depth=1 .....................................................
# [CV] max_depth=1 .....................................................
# [CV] max_depth=1 .....................................................
# [CV] ...................................... max_depth=1, total=   0.0s
# [CV] ...................................... max_depth=1, total=   0.0s
# [CV] max_depth=1 .....................................................
# [CV] max_depth=11 ....................................................
# [CV] ...................................... max_depth=1, total=   0.0s
# [CV] ...................................... max_depth=1, total=   0.0s
# [CV] ...................................... max_depth=1, total=   0.0s
# [CV] max_depth=11 ....................................................
# [CV] max_depth=11 ....................................................
# [CV] max_depth=11 ....................................................
# [CV] ..................................... max_depth=11, total=   0.2s
# [CV] max_depth=21 ....................................................
# [CV] ..................................... max_depth=11, total=   0.2s
# [CV] max_depth=11 ....................................................
# [CV] ..................................... max_depth=11, total=   0.2s
# [CV] ..................................... max_depth=11, total=   0.2s
# [CV] max_depth=41 ....................................................
# [CV] max_depth=51 ....................................................
# [CV] ..................................... max_depth=11, total=   0.2s
# [CV] max_depth=21 ....................................................
# [CV] ..................................... max_depth=21, total=   0.3s
# [CV] max_depth=31 ....................................................
# [CV] ..................................... max_depth=41, total=   0.4s
# [CV] max_depth=41 ....................................................
# [CV] ..................................... max_depth=51, total=   0.5s
# [CV] max_depth=51 ....................................................
# [CV] ..................................... max_depth=21, total=   0.4s
# [CV] max_depth=21 ....................................................
# [CV] ..................................... max_depth=31, total=   0.4s
# [CV] max_depth=31 ....................................................
# [CV] ..................................... max_depth=41, total=   0.5s
# [CV] max_depth=41 ....................................................
# [CV] ..................................... max_depth=21, total=   0.3s
# [CV] max_depth=21 ....................................................
# [CV] ..................................... max_depth=51, total=   0.4s
# [CV] max_depth=51 ....................................................
# [CV] ..................................... max_depth=31, total=   0.5s
# [CV] max_depth=31 ....................................................
# [CV] ..................................... max_depth=21, total=   0.3s
# [CV] max_depth=21 ....................................................
# [CV] ..................................... max_depth=41, total=   0.5s
# [CV] max_depth=41 ....................................................
# [CV] ..................................... max_depth=51, total=   0.5s
# [CV] max_depth=51 ....................................................
# [CV] ..................................... max_depth=21, total=   0.4s
# [CV] max_depth=61 ....................................................
# [CV] ..................................... max_depth=31, total=   0.5s
# [CV] max_depth=31 ....................................................
# [CV] ..................................... max_depth=41, total=   0.6s
# [CV] max_depth=41 ....................................................
# [CV] ..................................... max_depth=51, total=   0.5s
# [CV] max_depth=61 ....................................................
# [CV] ..................................... max_depth=31, total=   0.4s
# [CV] max_depth=31 ....................................................
# [CV] ..................................... max_depth=61, total=   0.5s
# [CV] max_depth=61 ....................................................
# [CV] ..................................... max_depth=41, total=   0.5s
# [CV] max_depth=51 ....................................................
# [CV] ..................................... max_depth=31, total=   0.4s
# [CV] max_depth=71 ....................................................
# [CV] ..................................... max_depth=61, total=   0.6s
# [CV] max_depth=61 ....................................................
# [CV] ..................................... max_depth=61, total=   0.5s
# [CV] max_depth=61 ....................................................
# [CV] ..................................... max_depth=51, total=   0.4s
# [CV] max_depth=81 ....................................................
# [CV] ..................................... max_depth=71, total=   0.5s
# [CV] max_depth=71 ....................................................
# [CV] ..................................... max_depth=61, total=   0.4s
# [CV] max_depth=101 ...................................................
# [CV] ..................................... max_depth=61, total=   0.6s
# [CV] max_depth=71 ....................................................
# [CV] ..................................... max_depth=81, total=   0.5s
# [CV] max_depth=91 ....................................................
# [CV] ..................................... max_depth=71, total=   0.5s
# [CV] max_depth=81 ....................................................
# [CV] .................................... max_depth=101, total=   0.4s
# [CV] max_depth=101 ...................................................
# [CV] ..................................... max_depth=71, total=   0.5s
# [CV] max_depth=71 ....................................................
# [CV] ..................................... max_depth=91, total=   0.5s
# [CV] max_depth=91 ....................................................
# [CV] ..................................... max_depth=81, total=   0.4s
# [CV] max_depth=81 ....................................................
# [CV] .................................... max_depth=101, total=   0.6s
# [CV] max_depth=101 ...................................................
# [CV] ..................................... max_depth=71, total=   0.5s
# [CV] max_depth=71 ....................................................
# [CV] ..................................... max_depth=81, total=   0.5s
# [CV] max_depth=81 ....................................................
# [CV] ..................................... max_depth=91, total=   0.5s
# [CV] max_depth=91 ....................................................
# [CV] ..................................... max_depth=71, total=   0.4s
# [CV] max_depth=111 ...................................................
# [CV] .................................... max_depth=101, total=   0.6s
# [CV] max_depth=101 ...................................................
# [CV] ..................................... max_depth=81, total=   0.4s
# [CV] max_depth=81 ....................................................
# [CV] ..................................... max_depth=91, total=   0.5s
# [CV] max_depth=91 ....................................................
# [CV] .................................... max_depth=111, total=   0.5s
# [CV] max_depth=111 ...................................................
# [CV] .................................... max_depth=101, total=   0.6s
# [CV] max_depth=101 ...................................................
# [CV] ..................................... max_depth=81, total=   0.5s
# [CV] max_depth=121 ...................................................
# [CV] ..................................... max_depth=91, total=   0.5s
# [CV] max_depth=91 ....................................................
# [CV] .................................... max_depth=111, total=   0.5s
# [CV] max_depth=111 ...................................................
# [CV] .................................... max_depth=101, total=   0.5s
# [CV] max_depth=111 ...................................................
# [CV] .................................... max_depth=121, total=   0.6s
# [CV] max_depth=121 ...................................................
# [CV] ..................................... max_depth=91, total=   0.5s
# [CV] max_depth=131 ...................................................
# [CV] .................................... max_depth=111, total=   0.5s
# [CV] max_depth=111 ...................................................
# [CV] .................................... max_depth=111, total=   0.5s
# [CV] max_depth=131 ...................................................
# [CV] .................................... max_depth=131, total=   0.5s
# [CV] max_depth=131 ...................................................
# [CV] .................................... max_depth=121, total=   0.5s
# [CV] max_depth=121 ...................................................
# [CV] .................................... max_depth=111, total=   0.5s
# [CV] max_depth=121 ...................................................
# [CV] .................................... max_depth=131, total=   0.5s
# [CV] max_depth=131 ...................................................
# [CV] .................................... max_depth=131, total=   0.5s
# [CV] max_depth=131 ...................................................
# [CV] .................................... max_depth=121, total=   0.5s
# [CV] max_depth=141 ...................................................
# [CV] .................................... max_depth=121, total=   0.5s
# [CV] max_depth=121 ...................................................
# [CV] .................................... max_depth=131, total=   0.5s
# [CV] max_depth=141 ...................................................
# [CV] .................................... max_depth=131, total=   0.5s
# [CV] max_depth=141 ...................................................
# [CV] .................................... max_depth=141, total=   0.5s
# [CV] max_depth=141 ...................................................
# [CV] .................................... max_depth=121, total=   0.5s
# [CV] max_depth=151 ...................................................
# [CV] .................................... max_depth=141, total=   0.5s
# [CV] max_depth=161 ...................................................
# [CV] .................................... max_depth=141, total=   0.5s
# [CV] max_depth=151 ...................................................
# [CV] .................................... max_depth=141, total=   0.5s
# [CV] max_depth=141 ...................................................
# [CV] .................................... max_depth=151, total=   0.4s
# [CV] max_depth=151 ...................................................
# [CV] .................................... max_depth=161, total=   0.5s
# [CV] max_depth=161 ...................................................
# [CV] .................................... max_depth=141, total=   0.5s
# [CV] .................................... max_depth=151, total=   0.5s
# [CV] max_depth=161 ...................................................
# [CV] max_depth=151 ...................................................
# [CV] .................................... max_depth=151, total=   0.5s
# [CV] max_depth=151 ...................................................
# [CV] .................................... max_depth=161, total=   0.5s
# [CV] max_depth=161 ...................................................
# [CV] .................................... max_depth=151, total=   0.4s
# [CV] .................................... max_depth=161, total=   0.5s
# [CV] max_depth=171 ...................................................
# [CV] max_depth=161 ...................................................
# [CV] .................................... max_depth=151, total=   0.5s
# [CV] max_depth=171 ...................................................
# [CV] .................................... max_depth=161, total=   0.5s
# [CV] max_depth=171 ...................................................
# [CV] .................................... max_depth=171, total=   0.5s
# [CV] max_depth=171 ...................................................
# [CV] .................................... max_depth=161, total=   0.5s
# [CV] max_depth=171 ...................................................
# [CV] .................................... max_depth=171, total=   0.4s
# [CV] max_depth=181 ...................................................
# [CV] .................................... max_depth=171, total=   0.5s
# [CV] max_depth=181 ...................................................
# [CV] .................................... max_depth=171, total=   0.4s
# [CV] max_depth=181 ...................................................
# [CV] .................................... max_depth=171, total=   0.6s
# [CV] .................................... max_depth=181, total=   0.5s
# [CV] max_depth=181 ...................................................
# [CV] max_depth=181 ...................................................
# [CV] .................................... max_depth=181, total=   0.5s
# [CV] max_depth=191 ...................................................
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:   10.7s
# [CV] .................................... max_depth=181, total=   0.5s
# [CV] max_depth=191 ...................................................
# [CV] .................................... max_depth=181, total=   0.5s
# [CV] max_depth=191 ...................................................
# [CV] .................................... max_depth=181, total=   0.5s
# [CV] max_depth=191 ...................................................
# [CV] .................................... max_depth=191, total=   0.5s
# [CV] max_depth=191 ...................................................
# [CV] .................................... max_depth=191, total=   0.5s
# [CV] max_depth=201 ...................................................
# [CV] .................................... max_depth=191, total=   0.4s
# [CV] max_depth=201 ...................................................
# [CV] .................................... max_depth=191, total=   0.5s
# [CV] max_depth=201 ...................................................
# [CV] .................................... max_depth=191, total=   0.5s
# [CV] max_depth=201 ...................................................
# [CV] .................................... max_depth=201, total=   0.5s
# [CV] max_depth=201 ...................................................
# [CV] .................................... max_depth=201, total=   0.5s
# [CV] max_depth=211 ...................................................
# [CV] .................................... max_depth=201, total=   0.5s
# [CV] max_depth=211 ...................................................
# [CV] .................................... max_depth=201, total=   0.5s
# [CV] max_depth=211 ...................................................
# [CV] .................................... max_depth=201, total=   0.5s
# [CV] max_depth=211 ...................................................
# [CV] .................................... max_depth=211, total=   0.4s
# [CV] max_depth=211 ...................................................
# [CV] .................................... max_depth=211, total=   0.5s
# [CV] max_depth=221 ...................................................
# [CV] .................................... max_depth=211, total=   0.5s
# [CV] max_depth=221 ...................................................
# [CV] .................................... max_depth=211, total=   0.6s
# [CV] max_depth=221 ...................................................
# [CV] .................................... max_depth=221, total=   0.4s
# [CV] max_depth=221 ...................................................
# [CV] .................................... max_depth=211, total=   0.6s
# [CV] max_depth=221 ...................................................
# [CV] .................................... max_depth=221, total=   0.5s
# [CV] max_depth=231 ...................................................
# [CV] .................................... max_depth=221, total=   0.5s
# [CV] max_depth=231 ...................................................
# [CV] .................................... max_depth=221, total=   0.5s
# [CV] max_depth=231 ...................................................
# [CV] .................................... max_depth=221, total=   0.5s
# [CV] max_depth=231 ...................................................
# [CV] .................................... max_depth=231, total=   0.5s
# [CV] max_depth=231 ...................................................
# [CV] .................................... max_depth=231, total=   0.4s
# [CV] max_depth=241 ...................................................
# [CV] .................................... max_depth=231, total=   0.5s
# [CV] max_depth=241 ...................................................
# [CV] .................................... max_depth=231, total=   0.5s
# [CV] max_depth=241 ...................................................
# [CV] .................................... max_depth=231, total=   0.6s
# [CV] max_depth=241 ...................................................
# [CV] .................................... max_depth=241, total=   0.4s
# [CV] max_depth=241 ...................................................
# [CV] .................................... max_depth=241, total=   0.5s
# [CV] max_depth=251 ...................................................
# [CV] .................................... max_depth=241, total=   0.6s
# [CV] max_depth=251 ...................................................
# [CV] .................................... max_depth=241, total=   0.5s
# [CV] max_depth=251 ...................................................
# [CV] .................................... max_depth=241, total=   0.5s
# [CV] max_depth=251 ...................................................
# [CV] .................................... max_depth=251, total=   0.5s
# [CV] max_depth=251 ...................................................
# [CV] .................................... max_depth=251, total=   0.5s
# [CV] max_depth=261 ...................................................
# [CV] .................................... max_depth=251, total=   0.5s
# [CV] max_depth=261 ...................................................
# [CV] .................................... max_depth=251, total=   0.6s
# [CV] max_depth=261 ...................................................
# [CV] .................................... max_depth=251, total=   0.5s
# [CV] max_depth=261 ...................................................
# [CV] .................................... max_depth=261, total=   0.5s
# [CV] max_depth=261 ...................................................
# [CV] .................................... max_depth=261, total=   0.5s
# [CV] max_depth=271 ...................................................
# [CV] .................................... max_depth=261, total=   0.5s
# [CV] max_depth=271 ...................................................
# [CV] .................................... max_depth=261, total=   0.5s
# [CV] max_depth=271 ...................................................
# [CV] .................................... max_depth=261, total=   0.5s
# [CV] max_depth=271 ...................................................
# [CV] .................................... max_depth=271, total=   0.5s
# [CV] max_depth=271 ...................................................
# [CV] .................................... max_depth=271, total=   0.6s
# [CV] max_depth=281 ...................................................
# [CV] .................................... max_depth=271, total=   0.5s
# [CV] max_depth=281 ...................................................
# [CV] .................................... max_depth=271, total=   0.5s
# [CV] max_depth=281 ...................................................
# [CV] .................................... max_depth=271, total=   0.6s
# [CV] .................................... max_depth=281, total=   0.5s
# [CV] max_depth=281 ...................................................
# [CV] max_depth=281 ...................................................
# [CV] .................................... max_depth=281, total=   0.4s
# [CV] .................................... max_depth=281, total=   0.5s
# [CV] max_depth=291 ...................................................
# [CV] max_depth=291 ...................................................
# [CV] .................................... max_depth=281, total=   0.6s
# [CV] max_depth=291 ...................................................
# [CV] .................................... max_depth=291, total=   0.5s
# [CV] .................................... max_depth=281, total=   0.6s
# [CV] max_depth=291 ...................................................
# [CV] max_depth=291 ...................................................
# [CV] .................................... max_depth=291, total=   0.5s
# [CV] max_depth=301 ...................................................
# [CV] .................................... max_depth=291, total=   0.5s
# [CV] max_depth=301 ...................................................
# [CV] .................................... max_depth=291, total=   0.6s
# [CV] max_depth=301 ...................................................
# [CV] .................................... max_depth=301, total=   0.6s
# [CV] .................................... max_depth=291, total=   0.7s
# [CV] max_depth=301 ...................................................
# [CV] max_depth=301 ...................................................
# [CV] .................................... max_depth=301, total=   0.5s
# [CV] max_depth=311 ...................................................
# [CV] .................................... max_depth=301, total=   0.6s
# [CV] max_depth=311 ...................................................
# [CV] .................................... max_depth=301, total=   0.6s
# [CV] max_depth=311 ...................................................
# [CV] .................................... max_depth=301, total=   0.6s
# [CV] max_depth=311 ...................................................
# [CV] .................................... max_depth=311, total=   0.4s
# [CV] max_depth=311 ...................................................
# [CV] .................................... max_depth=311, total=   0.4s
# [CV] max_depth=321 ...................................................
# [CV] .................................... max_depth=311, total=   0.4s
# [CV] max_depth=321 ...................................................
# [CV] .................................... max_depth=311, total=   0.5s
# [CV] max_depth=321 ...................................................
# [CV] .................................... max_depth=311, total=   0.5s
# [CV] max_depth=321 ...................................................
# [CV] .................................... max_depth=321, total=   0.5s
# [CV] max_depth=321 ...................................................
# [CV] .................................... max_depth=321, total=   0.6s
# [CV] max_depth=331 ...................................................
# [CV] .................................... max_depth=321, total=   0.5s
# [CV] max_depth=331 ...................................................
# [CV] .................................... max_depth=321, total=   0.6s
# [CV] max_depth=331 ...................................................
# [CV] .................................... max_depth=321, total=   0.5s
# [CV] max_depth=331 ...................................................
# [CV] .................................... max_depth=331, total=   0.5s
# [CV] max_depth=331 ...................................................
# [CV] .................................... max_depth=331, total=   0.6s
# [CV] max_depth=341 ...................................................
# [CV] .................................... max_depth=331, total=   0.5s
# [CV] max_depth=341 ...................................................
# [CV] .................................... max_depth=331, total=   0.6s
# [CV] max_depth=341 ...................................................
# [CV] .................................... max_depth=331, total=   0.6s
# [CV] max_depth=341 ...................................................
# [CV] .................................... max_depth=341, total=   0.6s
# [CV] max_depth=341 ...................................................
# [CV] .................................... max_depth=341, total=   0.5s
# [CV] max_depth=351 ...................................................
# [CV] .................................... max_depth=341, total=   0.5s
# [CV] max_depth=351 ...................................................
# [CV] .................................... max_depth=341, total=   0.5s
# [CV] max_depth=351 ...................................................
# [CV] .................................... max_depth=341, total=   0.5s
# [CV] max_depth=351 ...................................................
# [CV] .................................... max_depth=351, total=   0.5s
# [CV] max_depth=351 ...................................................
# [CV] .................................... max_depth=351, total=   0.5s
# [CV] max_depth=361 ...................................................
# [CV] .................................... max_depth=351, total=   0.4s
# [CV] max_depth=361 ...................................................
# [CV] .................................... max_depth=351, total=   0.5s
# [CV] max_depth=361 ...................................................
# [CV] .................................... max_depth=351, total=   0.5s
# [CV] max_depth=361 ...................................................
# [CV] .................................... max_depth=361, total=   0.5s
# [CV] max_depth=361 ...................................................
# [CV] .................................... max_depth=361, total=   0.5s
# [CV] max_depth=371 ...................................................
# [CV] .................................... max_depth=361, total=   0.5s
# [CV] max_depth=371 ...................................................
# [CV] .................................... max_depth=361, total=   0.6s
# [CV] max_depth=371 ...................................................
# [CV] .................................... max_depth=361, total=   0.5s
# [CV] max_depth=371 ...................................................
# [CV] .................................... max_depth=371, total=   0.4s
# [CV] max_depth=371 ...................................................
# [CV] .................................... max_depth=371, total=   0.5s
# [CV] max_depth=381 ...................................................
# [CV] .................................... max_depth=371, total=   0.5s
# [CV] max_depth=381 ...................................................
# [CV] .................................... max_depth=371, total=   0.6s
# [CV] .................................... max_depth=371, total=   0.4s
# [CV] max_depth=381 ...................................................
# [CV] max_depth=381 ...................................................
# [CV] .................................... max_depth=381, total=   0.4s
# [CV] max_depth=381 ...................................................
# [CV] .................................... max_depth=381, total=   0.4s
# [CV] max_depth=391 ...................................................
# [CV] .................................... max_depth=381, total=   0.4s
# [CV] max_depth=391 ...................................................
# [CV] .................................... max_depth=381, total=   0.5s
# [CV] max_depth=391 ...................................................
# [CV] .................................... max_depth=381, total=   0.5s
# [CV] max_depth=391 ...................................................
# [CV] .................................... max_depth=391, total=   0.4s
# [CV] max_depth=391 ...................................................
# [CV] .................................... max_depth=391, total=   0.5s
# [CV] .................................... max_depth=391, total=   0.5s
# [CV] .................................... max_depth=391, total=   0.5s
# [CV] .................................... max_depth=391, total=   0.3s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:   25.1s finished
# /home/pace/Documents/data_science/project-pace-mourad/adrian/src/plots.py:30: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if train_scores_std != None and val_scores_std != None:
# Best ['max_depth'] = {'max_depth': 11} with score : 0.6375
# Execution time : 26.262213945388794 seconds
# GridSearchCV(cv=5, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=0, splitter='best'),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'max_depth': range(1, 400, 10)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=2)

# %% [markdown]
# #### k nearest neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

parameter_search(KNeighborsClassifier(),
                {'n_neighbors':range(1,100,6)},
                X_train,
                y_train,save_file=save_location+'/knn.png')
# Out:
# Fitting 5 folds for each of 17 candidates, totalling 85 fits
# [CV] n_neighbors=1 ...................................................
# [CV] n_neighbors=1 ...................................................
# [CV] n_neighbors=1 ...................................................
# [CV] n_neighbors=1 ...................................................
# [CV] .................................... n_neighbors=1, total=   0.2s
# [CV] n_neighbors=1 ...................................................
# [CV] .................................... n_neighbors=1, total=   0.3s
# [CV] .................................... n_neighbors=1, total=   0.3s
# [CV] n_neighbors=7 ...................................................
# [CV] .................................... n_neighbors=1, total=   0.3s
# [CV] n_neighbors=7 ...................................................
# [CV] n_neighbors=7 ...................................................
# [CV] .................................... n_neighbors=1, total=   0.2s
# [CV] n_neighbors=7 ...................................................
# [CV] .................................... n_neighbors=7, total=   0.2s
# [CV] n_neighbors=7 ...................................................
# [CV] .................................... n_neighbors=7, total=   0.3s
# [CV] n_neighbors=13 ..................................................
# [CV] .................................... n_neighbors=7, total=   0.3s
# [CV] n_neighbors=13 ..................................................
# [CV] .................................... n_neighbors=7, total=   0.3s
# [CV] n_neighbors=13 ..................................................
# [CV] .................................... n_neighbors=7, total=   0.3s
# [CV] n_neighbors=13 ..................................................
# [CV] ................................... n_neighbors=13, total=   0.2s
# [CV] n_neighbors=13 ..................................................
# [CV] ................................... n_neighbors=13, total=   0.3s
# [CV] n_neighbors=19 ..................................................
# [CV] ................................... n_neighbors=13, total=   0.2s
# [CV] n_neighbors=19 ..................................................
# [CV] ................................... n_neighbors=13, total=   0.2s
# [CV] ................................... n_neighbors=13, total=   0.3s
# [CV] n_neighbors=19 ..................................................
# [CV] n_neighbors=19 ..................................................
# [CV] ................................... n_neighbors=19, total=   0.2s
# [CV] n_neighbors=19 ..................................................
# [CV] ................................... n_neighbors=19, total=   0.2s
# [CV] n_neighbors=25 ..................................................
# [CV] ................................... n_neighbors=19, total=   0.3s
# [CV] ................................... n_neighbors=19, total=   0.3s
# [CV] n_neighbors=25 ..................................................
# [CV] n_neighbors=25 ..................................................
# [CV] ................................... n_neighbors=19, total=   0.2s
# [CV] n_neighbors=25 ..................................................
# [CV] ................................... n_neighbors=25, total=   0.3s
# [CV] n_neighbors=25 ..................................................
# [CV] ................................... n_neighbors=25, total=   0.3s
# [CV] n_neighbors=31 ..................................................
# [CV] ................................... n_neighbors=25, total=   0.3s
# [CV] ................................... n_neighbors=25, total=   0.3s
# [CV] n_neighbors=31 ..................................................
# [CV] n_neighbors=31 ..................................................
# [CV] ................................... n_neighbors=25, total=   0.3s
# [CV] n_neighbors=31 ..................................................
# [CV] ................................... n_neighbors=31, total=   0.3s
# [CV] n_neighbors=31 ..................................................
# [CV] ................................... n_neighbors=31, total=   0.2s
# [CV] n_neighbors=37 ..................................................
# [CV] ................................... n_neighbors=31, total=   0.4s
# [CV] n_neighbors=37 ..................................................
# [CV] ................................... n_neighbors=31, total=   0.3s
# [CV] n_neighbors=37 ..................................................
# [CV] ................................... n_neighbors=31, total=   0.3s
# [CV] n_neighbors=37 ..................................................
# [CV] ................................... n_neighbors=37, total=   0.3s
# [CV] n_neighbors=37 ..................................................
# [CV] ................................... n_neighbors=37, total=   0.4s
# [CV] n_neighbors=43 ..................................................
# [CV] ................................... n_neighbors=37, total=   0.3s
# [CV] n_neighbors=43 ..................................................
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   13.8s
# [CV] ................................... n_neighbors=37, total=   0.3s
# [CV] ................................... n_neighbors=37, total=   0.3s
# [CV] n_neighbors=43 ..................................................
# [CV] n_neighbors=43 ..................................................
# [CV] ................................... n_neighbors=43, total=   0.3s
# [CV] n_neighbors=43 ..................................................
# [CV] ................................... n_neighbors=43, total=   0.3s
# [CV] n_neighbors=49 ..................................................
# [CV] ................................... n_neighbors=43, total=   0.2s
# [CV] n_neighbors=49 ..................................................
# [CV] ................................... n_neighbors=43, total=   0.3s
# [CV] ................................... n_neighbors=43, total=   0.2s
# [CV] n_neighbors=49 ..................................................
# [CV] n_neighbors=49 ..................................................
# [CV] ................................... n_neighbors=49, total=   0.3s
# [CV] n_neighbors=49 ..................................................
# [CV] ................................... n_neighbors=49, total=   0.3s
# [CV] n_neighbors=55 ..................................................
# [CV] ................................... n_neighbors=49, total=   0.3s
# [CV] n_neighbors=55 ..................................................
# [CV] ................................... n_neighbors=49, total=   0.3s
# [CV] n_neighbors=55 ..................................................
# [CV] ................................... n_neighbors=49, total=   0.3s
# [CV] n_neighbors=55 ..................................................
# [CV] ................................... n_neighbors=55, total=   0.3s
# [CV] n_neighbors=55 ..................................................
# [CV] ................................... n_neighbors=55, total=   0.3s
# [CV] n_neighbors=61 ..................................................
# [CV] ................................... n_neighbors=55, total=   0.3s
# [CV] n_neighbors=61 ..................................................
# [CV] ................................... n_neighbors=55, total=   0.3s
# [CV] n_neighbors=61 ..................................................
# [CV] ................................... n_neighbors=55, total=   0.3s
# [CV] n_neighbors=61 ..................................................
# [CV] ................................... n_neighbors=61, total=   0.4s
# [CV] n_neighbors=61 ..................................................
# [CV] ................................... n_neighbors=61, total=   0.4s
# [CV] n_neighbors=67 ..................................................
# [CV] ................................... n_neighbors=61, total=   0.3s
# [CV] n_neighbors=67 ..................................................
# [CV] ................................... n_neighbors=61, total=   0.3s
# [CV] ................................... n_neighbors=67, total=   0.3s
# [CV] n_neighbors=67 ..................................................
# [CV] n_neighbors=67 ..................................................
# [CV] ................................... n_neighbors=61, total=   0.3s
# [CV] n_neighbors=67 ..................................................
# [CV] ................................... n_neighbors=67, total=   0.2s
# [CV] n_neighbors=73 ..................................................
# [CV] ................................... n_neighbors=67, total=   0.3s
# [CV] n_neighbors=73 ..................................................
# [CV] ................................... n_neighbors=67, total=   0.4s
# [CV] n_neighbors=73 ..................................................
# [CV] ................................... n_neighbors=67, total=   0.3s
# [CV] n_neighbors=73 ..................................................
# [CV] ................................... n_neighbors=73, total=   0.3s
# [CV] n_neighbors=73 ..................................................
# [CV] ................................... n_neighbors=73, total=   1.0s
# [CV] n_neighbors=79 ..................................................
# [CV] ................................... n_neighbors=73, total=   1.0s
# [CV] n_neighbors=79 ..................................................
# [CV] ................................... n_neighbors=73, total=   0.9s
# [CV] ................................... n_neighbors=73, total=   1.1s
# [CV] n_neighbors=79 ..................................................
# [CV] n_neighbors=79 ..................................................
# [CV] ................................... n_neighbors=79, total=   0.5s
# [CV] n_neighbors=79 ..................................................
# [CV] ................................... n_neighbors=79, total=   0.5s
# [CV] n_neighbors=85 ..................................................
# [CV] ................................... n_neighbors=79, total=   0.6s
# [CV] n_neighbors=85 ..................................................
# [CV] ................................... n_neighbors=79, total=   0.4s
# [CV] n_neighbors=85 ..................................................
# [CV] ................................... n_neighbors=79, total=   0.7s
# [CV] n_neighbors=85 ..................................................
# [CV] ................................... n_neighbors=85, total=   0.4s
# [CV] n_neighbors=85 ..................................................
# [CV] ................................... n_neighbors=85, total=   0.4s
# [CV] n_neighbors=91 ..................................................
# [CV] ................................... n_neighbors=85, total=   0.3s
# [CV] n_neighbors=91 ..................................................
# [CV] ................................... n_neighbors=85, total=   0.3s
# [CV] n_neighbors=91 ..................................................
# [CV] ................................... n_neighbors=85, total=   0.4s
# [CV] n_neighbors=91 ..................................................
# [CV] ................................... n_neighbors=91, total=   0.3s
# [CV] n_neighbors=91 ..................................................
# [CV] ................................... n_neighbors=91, total=   0.3s
# [CV] n_neighbors=97 ..................................................
# [CV] ................................... n_neighbors=91, total=   0.4s
# [CV] n_neighbors=97 ..................................................
# [CV] ................................... n_neighbors=91, total=   0.3s
# [CV] n_neighbors=97 ..................................................
# [CV] ................................... n_neighbors=91, total=   0.3s
# [CV] n_neighbors=97 ..................................................
# [CV] ................................... n_neighbors=97, total=   0.3s
# [CV] n_neighbors=97 ..................................................
# [CV] ................................... n_neighbors=97, total=   0.4s
# [CV] ................................... n_neighbors=97, total=   0.3s
# [CV] ................................... n_neighbors=97, total=   0.4s
# [CV] ................................... n_neighbors=97, total=   0.3s
# [Parallel(n_jobs=-1)]: Done  85 out of  85 | elapsed:   37.6s finished
# /home/pace/Documents/data_science/project-pace-mourad/adrian/src/plots.py:30: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if train_scores_std != None and val_scores_std != None:
# Best ['n_neighbors'] = {'n_neighbors': 73} with score : 0.6165
# Execution time : 38.71186423301697 seconds
# GridSearchCV(cv=5, error_score='raise',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform'),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'n_neighbors': range(1, 100, 6)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=2)

# %% [markdown]
# #### SVM

# %%
parameter_search(SVC(),
                {'C':np.logspace(-5,5,15)},
                X_train,
                y_train,save_file=save_location+'/svm.png')
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV] C=1e-05 .........................................................
# [CV] C=1e-05 .........................................................
# [CV] C=1e-05 .........................................................
# [CV] C=1e-05 .........................................................
# [CV] .......................................... C=1e-05, total=   4.1s
# [CV] C=1e-05 .........................................................
# [CV] .......................................... C=1e-05, total=   4.6s
# [CV] C=5.17947467923e-05 .............................................
# [CV] .......................................... C=1e-05, total=   4.5s
# [CV] C=5.17947467923e-05 .............................................
# [CV] .......................................... C=1e-05, total=   4.7s
# [CV] C=5.17947467923e-05 .............................................
# [CV] .......................................... C=1e-05, total=   4.0s
# [CV] C=5.17947467923e-05 .............................................
# [CV] .............................. C=5.17947467923e-05, total=   3.7s
# [CV] C=5.17947467923e-05 .............................................
# [CV] .............................. C=5.17947467923e-05, total=   4.0s
# [CV] C=0.000268269579528 .............................................
# [CV] .............................. C=5.17947467923e-05, total=   4.0s
# [CV] C=0.000268269579528 .............................................
# [CV] .............................. C=5.17947467923e-05, total=   4.4s
# [CV] C=0.000268269579528 .............................................
# [CV] .............................. C=5.17947467923e-05, total=   4.0s
# [CV] C=0.000268269579528 .............................................
# [CV] .............................. C=0.000268269579528, total=   3.8s
# [CV] C=0.000268269579528 .............................................
# [CV] .............................. C=0.000268269579528, total=   4.2s
# [CV] C=0.00138949549437 ..............................................
# [CV] .............................. C=0.000268269579528, total=   3.5s
# [CV] C=0.00138949549437 ..............................................
# [CV] .............................. C=0.000268269579528, total=   3.5s
# [CV] C=0.00138949549437 ..............................................
# [CV] ............................... C=0.00138949549437, total=   4.0s
# [CV] C=0.00138949549437 ..............................................
# [CV] .............................. C=0.000268269579528, total=   4.1s
# [CV] C=0.00138949549437 ..............................................
# [CV] ............................... C=0.00138949549437, total=   4.0s
# [CV] C=0.00719685673001 ..............................................
# [CV] ............................... C=0.00138949549437, total=   4.7s
# [CV] C=0.00719685673001 ..............................................
# [CV] ............................... C=0.00138949549437, total=   4.4s
# [CV] C=0.00719685673001 ..............................................
# [CV] ............................... C=0.00138949549437, total=   4.6s
# [CV] C=0.00719685673001 ..............................................
# [CV] ............................... C=0.00719685673001, total=   5.9s
# [CV] C=0.00719685673001 ..............................................
# [CV] ............................... C=0.00719685673001, total=   7.4s
# [CV] C=0.0372759372031 ...............................................
# [CV] ............................... C=0.00719685673001, total=   7.5s
# [CV] C=0.0372759372031 ...............................................
# [CV] ............................... C=0.00719685673001, total=   7.9s
# [CV] C=0.0372759372031 ...............................................
# [CV] ............................... C=0.00719685673001, total=   5.2s
# [CV] C=0.0372759372031 ...............................................
# [CV] ................................ C=0.0372759372031, total=   4.7s
# [CV] C=0.0372759372031 ...............................................
# [CV] ................................ C=0.0372759372031, total=   4.8s
# [CV] C=0.193069772888 ................................................
# [CV] ................................ C=0.0372759372031, total=   4.6s
# [CV] C=0.193069772888 ................................................
# [CV] ................................ C=0.0372759372031, total=   4.4s
# [CV] C=0.193069772888 ................................................
# [CV] ................................ C=0.0372759372031, total=   4.3s
# [CV] C=0.193069772888 ................................................
# [CV] ................................. C=0.193069772888, total=   4.0s
# [CV] C=0.193069772888 ................................................
# [CV] ................................. C=0.193069772888, total=   4.0s
# [CV] C=1.0 ...........................................................
# [CV] ................................. C=0.193069772888, total=   3.7s
# [CV] C=1.0 ...........................................................
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.1min
# [CV] ................................. C=0.193069772888, total=   3.5s
# [CV] C=1.0 ...........................................................
# [CV] ............................................ C=1.0, total=   3.4s
# [CV] C=1.0 ...........................................................
# [CV] ................................. C=0.193069772888, total=   3.5s
# [CV] C=1.0 ...........................................................
# [CV] ............................................ C=1.0, total=   3.2s
# [CV] C=5.17947467923 .................................................
# [CV] ............................................ C=1.0, total=   3.4s
# [CV] C=5.17947467923 .................................................
# [CV] ............................................ C=1.0, total=   3.3s
# [CV] C=5.17947467923 .................................................
# [CV] ............................................ C=1.0, total=   3.7s
# [CV] C=5.17947467923 .................................................
# [CV] .................................. C=5.17947467923, total=   4.2s
# [CV] C=5.17947467923 .................................................
# [CV] .................................. C=5.17947467923, total=   4.1s
# [CV] C=26.8269579528 .................................................
# [CV] .................................. C=5.17947467923, total=   3.8s
# [CV] C=26.8269579528 .................................................
# [CV] .................................. C=5.17947467923, total=   3.9s
# [CV] C=26.8269579528 .................................................
# [CV] .................................. C=5.17947467923, total=   3.6s
# [CV] C=26.8269579528 .................................................
# [CV] .................................. C=26.8269579528, total=   3.6s
# [CV] C=26.8269579528 .................................................
# [CV] .................................. C=26.8269579528, total=   3.5s
# [CV] C=138.949549437 .................................................
# [CV] .................................. C=26.8269579528, total=   3.2s
# [CV] C=138.949549437 .................................................
# [CV] .................................. C=26.8269579528, total=   3.7s
# [CV] C=138.949549437 .................................................
# [CV] .................................. C=26.8269579528, total=   4.0s
# [CV] C=138.949549437 .................................................
# [CV] .................................. C=138.949549437, total=   4.2s
# [CV] C=138.949549437 .................................................
# [CV] .................................. C=138.949549437, total=   4.0s
# [CV] C=719.685673001 .................................................
# [CV] .................................. C=138.949549437, total=   3.5s
# [CV] C=719.685673001 .................................................
# [CV] .................................. C=138.949549437, total=   3.2s
# [CV] C=719.685673001 .................................................
# [CV] .................................. C=719.685673001, total=   3.6s
# [CV] C=719.685673001 .................................................
# [CV] .................................. C=138.949549437, total=   3.5s
# [CV] C=719.685673001 .................................................
# [CV] .................................. C=719.685673001, total=   3.9s
# [CV] C=3727.59372031 .................................................
# [CV] .................................. C=719.685673001, total=   3.9s
# [CV] C=3727.59372031 .................................................
# [CV] .................................. C=719.685673001, total=   4.1s
# [CV] C=3727.59372031 .................................................
# [CV] .................................. C=719.685673001, total=   4.2s
# [CV] C=3727.59372031 .................................................
# [CV] .................................. C=3727.59372031, total=   6.3s
# [CV] C=3727.59372031 .................................................
# [CV] .................................. C=3727.59372031, total=   6.2s
# [CV] C=19306.9772888 .................................................
# [CV] .................................. C=3727.59372031, total=   7.5s
# [CV] C=19306.9772888 .................................................
# [CV] .................................. C=3727.59372031, total=   7.9s
# [CV] C=19306.9772888 .................................................
# [CV] .................................. C=3727.59372031, total=   7.1s
# [CV] C=19306.9772888 .................................................
# [CV] .................................. C=19306.9772888, total=  18.0s
# [CV] C=19306.9772888 .................................................
# [CV] .................................. C=19306.9772888, total=  22.2s
# [CV] C=100000.0 ......................................................
# [CV] .................................. C=19306.9772888, total=  21.5s
# [CV] C=100000.0 ......................................................
# [CV] .................................. C=19306.9772888, total=  20.3s
# [CV] C=100000.0 ......................................................
# [CV] .................................. C=19306.9772888, total=  15.0s
# [CV] C=100000.0 ......................................................
# [CV] ....................................... C=100000.0, total=  38.1s
# [CV] C=100000.0 ......................................................
# [CV] ....................................... C=100000.0, total=  38.2s
# [CV] ....................................... C=100000.0, total=  46.3s
# [CV] ....................................... C=100000.0, total=  37.6s
# [CV] ....................................... C=100000.0, total=  19.5s
# [Parallel(n_jobs=-1)]: Done  75 out of  75 | elapsed:  3.3min finished
# /home/pace/Documents/data_science/project-pace-mourad/adrian/src/plots.py:30: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if train_scores_std != None and val_scores_std != None:
# Best ['C'] = {'C': 719.68567300115285} with score : 0.7185
# Execution time : 204.3917272090912 seconds
# GridSearchCV(cv=5, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': array([  1.00000e-05,   5.17947e-05,   2.68270e-04,   1.38950e-03,
#          7.19686e-03,   3.72759e-02,   1.93070e-01,   1.00000e+00,
#          5.17947e+00,   2.68270e+01,   1.38950e+02,   7.19686e+02,
#          3.72759e+03,   1.93070e+04,   1.00000e+05])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=2)

# %% [markdown]
# #### Logistic classifier

# %%
parameter_search(LogisticRegression(),
                {'C':np.logspace(-5,5,40)},
                X_train,
                y_train, save_file=save_location+'/log_reg.png')
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] C=1e-05 .........................................................
# [CV] C=1e-05 .........................................................
# [CV] C=1e-05 .........................................................
# [CV] C=1e-05 .........................................................
# [CV] .......................................... C=1e-05, total=   0.1s
# [CV] .......................................... C=1e-05, total=   0.1s
# [CV] .......................................... C=1e-05, total=   0.1s
# [CV] .......................................... C=1e-05, total=   0.1s
# [CV] C=1e-05 .........................................................
# [CV] C=1.80472176683e-05 .............................................
# [CV] C=1.80472176683e-05 .............................................
# [CV] C=1.80472176683e-05 .............................................
# [CV] .............................. C=1.80472176683e-05, total=   0.0s
# [CV] C=1.80472176683e-05 .............................................
# [CV] .......................................... C=1e-05, total=   0.0s
# [CV] C=3.25702065566e-05 .............................................
# [CV] .............................. C=1.80472176683e-05, total=   0.0s
# [CV] C=3.25702065566e-05 .............................................
# [CV] .............................. C=1.80472176683e-05, total=   0.0s
# [CV] .............................. C=3.25702065566e-05, total=   0.0s
# [CV] .............................. C=1.80472176683e-05, total=   0.1s
# [CV] C=3.25702065566e-05 .............................................
# [CV] C=1.80472176683e-05 .............................................
# [CV] C=3.25702065566e-05 .............................................
# [CV] .............................. C=1.80472176683e-05, total=   0.0s
# [CV] .............................. C=3.25702065566e-05, total=   0.0s
# [CV] C=5.87801607227e-05 .............................................
# [CV] .............................. C=3.25702065566e-05, total=   0.1s
# [CV] C=3.25702065566e-05 .............................................
# [CV] C=5.87801607227e-05 .............................................
# [CV] .............................. C=5.87801607227e-05, total=   0.0s
# [CV] .............................. C=5.87801607227e-05, total=   0.0s
# [CV] .............................. C=3.25702065566e-05, total=   0.0s
# [CV] .............................. C=3.25702065566e-05, total=   0.1s
# [CV] C=5.87801607227e-05 .............................................
# [CV] C=5.87801607227e-05 .............................................
# [CV] C=0.000106081835514 .............................................
# [CV] C=5.87801607227e-05 .............................................
# [CV] .............................. C=0.000106081835514, total=   0.0s
# [CV] C=0.000106081835514 .............................................
# [CV] .............................. C=5.87801607227e-05, total=   0.1s
# [CV] .............................. C=5.87801607227e-05, total=   0.0s
# [CV] .............................. C=5.87801607227e-05, total=   0.0s
# [CV] C=0.000106081835514 .............................................
# [CV] C=0.000106081835514 .............................................
# [CV] C=0.000191448197617 .............................................
# [CV] .............................. C=0.000106081835514, total=   0.1s
# [CV] C=0.000345510729459 .............................................
# [CV] .............................. C=0.000106081835514, total=   0.0s
# [CV] C=0.000106081835514 .............................................
# [CV] .............................. C=0.000191448197617, total=   0.0s
# [CV] .............................. C=0.000345510729459, total=   0.0s
# [CV] C=0.000191448197617 .............................................
# [CV] C=0.000345510729459 .............................................
# [CV] .............................. C=0.000106081835514, total=   0.1s
# [CV] .............................. C=0.000106081835514, total=   0.0s
# [CV] C=0.000191448197617 .............................................
# [CV] .............................. C=0.000191448197617, total=   0.0s
# [CV] C=0.000623550734127 .............................................
# [CV] C=0.000345510729459 .............................................
# [CV] .............................. C=0.000345510729459, total=   0.1s
# [CV] C=0.000345510729459 .............................................
# [CV] .............................. C=0.000191448197617, total=   0.1s
# [CV] C=0.000191448197617 .............................................
# [CV] .............................. C=0.000345510729459, total=   0.0s
# [CV] .............................. C=0.000623550734127, total=   0.0s
# [CV] C=0.000345510729459 .............................................
# [CV] C=0.000623550734127 .............................................
# [CV] .............................. C=0.000345510729459, total=   0.0s
# [CV] C=0.000623550734127 .............................................
# [CV] .............................. C=0.000191448197617, total=   0.1s
# [CV] .............................. C=0.000623550734127, total=   0.0s
# [CV] .............................. C=0.000345510729459, total=   0.0s
# [CV] C=0.000623550734127 .............................................
# [CV] C=0.0011253355826 ...............................................
# [CV] C=0.000191448197617 .............................................
# [CV] .............................. C=0.000623550734127, total=   0.1s
# [CV] .............................. C=0.000191448197617, total=   0.0s
# [CV] .............................. C=0.000623550734127, total=   0.0s
# [CV] C=0.000623550734127 .............................................
# [CV] C=0.0011253355826 ...............................................
# [CV] C=0.0020309176209 ...............................................
# [CV] ................................ C=0.0011253355826, total=   0.1s
# [CV] C=0.0011253355826 ...............................................
# [CV] ................................ C=0.0020309176209, total=   0.1s
# [CV] ................................ C=0.0011253355826, total=   0.1s
# [CV] .............................. C=0.000623550734127, total=   0.1s
# [CV] C=0.0020309176209 ...............................................
# [CV] C=0.0020309176209 ...............................................
# [CV] C=0.00366524123708 ..............................................
# [CV] ................................ C=0.0011253355826, total=   0.1s
# [CV] C=0.0011253355826 ...............................................
# [CV] ................................ C=0.0020309176209, total=   0.1s
# [CV] C=0.0020309176209 ...............................................
# [CV] ............................... C=0.00366524123708, total=   0.1s
# [CV] ................................ C=0.0020309176209, total=   0.1s
# [CV] C=0.00366524123708 ..............................................
# [CV] C=0.00366524123708 ..............................................
# [CV] ................................ C=0.0011253355826, total=   0.1s
# [CV] C=0.0011253355826 ...............................................
# [CV] ................................ C=0.0020309176209, total=   0.0s
# [CV] C=0.0020309176209 ...............................................
# [CV] ............................... C=0.00366524123708, total=   0.1s
# [CV] ............................... C=0.00366524123708, total=   0.1s
# [CV] ................................ C=0.0011253355826, total=   0.0s
# [CV] C=0.00366524123708 ..............................................
# [CV] C=0.00661474064123 ..............................................
# [CV] ................................ C=0.0020309176209, total=   0.0s
# [CV] C=0.00366524123708 ..............................................
# [CV] C=0.0119377664171 ...............................................
# [CV] ............................... C=0.00366524123708, total=   0.1s
# [CV] C=0.00661474064123 ..............................................
# [CV] ................................ C=0.0119377664171, total=   0.1s
# [CV] ............................... C=0.00366524123708, total=   0.1s
# [CV] C=0.0119377664171 ...............................................
# [CV] ............................... C=0.00661474064123, total=   0.1s
# [CV] C=0.00661474064123 ..............................................
# [CV] C=0.0119377664171 ...............................................
# [CV] ................................ C=0.0119377664171, total=   0.1s
# [CV] ............................... C=0.00661474064123, total=   0.1s
# [CV] C=0.0119377664171 ...............................................
# [CV] C=0.0215443469003 ...............................................
# [CV] ................................ C=0.0119377664171, total=   0.1s
# [CV] C=0.0215443469003 ...............................................
# [CV] ............................... C=0.00661474064123, total=   0.1s
# [CV] C=0.00661474064123 ..............................................
# [CV] ................................ C=0.0119377664171, total=   0.1s
# [CV] C=0.0119377664171 ...............................................
# [CV] ................................ C=0.0215443469003, total=   0.1s
# [CV] C=0.0215443469003 ...............................................
# [CV] ............................... C=0.00661474064123, total=   0.1s
# [CV] C=0.00661474064123 ..............................................
# [CV] ................................ C=0.0119377664171, total=   0.1s
# [CV] C=0.0388815518031 ...............................................
# [CV] ................................ C=0.0215443469003, total=   0.1s
# [CV] C=0.0388815518031 ...............................................
# [CV] ................................ C=0.0215443469003, total=   0.2s
# [CV] C=0.0215443469003 ...............................................
# [CV] ............................... C=0.00661474064123, total=   0.1s
# [CV] C=0.070170382867 ................................................
# [CV] ................................ C=0.0388815518031, total=   0.1s
# [CV] C=0.0388815518031 ...............................................
# [CV] ................................ C=0.0215443469003, total=   0.1s
# [CV] C=0.0215443469003 ...............................................
# [CV] ................................ C=0.0388815518031, total=   0.2s
# [CV] C=0.0388815518031 ...............................................
# [CV] ................................ C=0.0388815518031, total=   0.1s
# [CV] ................................. C=0.070170382867, total=   0.1s
# [CV] C=0.0388815518031 ...............................................
# [CV] C=0.070170382867 ................................................
# [CV] ................................ C=0.0215443469003, total=   0.1s
# [CV] C=0.126638017347 ................................................
# [CV] ................................ C=0.0388815518031, total=   0.1s
# [CV] ................................ C=0.0388815518031, total=   0.1s
# [CV] C=0.070170382867 ................................................
# [CV] C=0.126638017347 ................................................
# [CV] ................................. C=0.070170382867, total=   0.2s
# [CV] C=0.070170382867 ................................................
# [CV] ................................. C=0.070170382867, total=   0.1s
# [CV] C=0.070170382867 ................................................
# [CV] ................................. C=0.070170382867, total=   0.2s
# [CV] ................................. C=0.126638017347, total=   0.2s
# [CV] ................................. C=0.126638017347, total=   0.2s
# [CV] C=0.126638017347 ................................................
# [CV] C=0.228546386413 ................................................
# [CV] C=0.228546386413 ................................................
# [CV] ................................. C=0.070170382867, total=   0.2s
# [CV] ................................. C=0.126638017347, total=   0.1s
# [CV] C=0.126638017347 ................................................
# [CV] C=0.41246263829 .................................................
# [CV] ................................. C=0.228546386413, total=   0.2s
# [CV] C=0.228546386413 ................................................
# [CV] ................................. C=0.228546386413, total=   0.2s
# [CV] C=0.228546386413 ................................................
# [CV] ................................. C=0.126638017347, total=   0.1s
# [CV] C=0.126638017347 ................................................
# [CV] .................................. C=0.41246263829, total=   0.2s
# [CV] C=0.41246263829 .................................................
# [CV] ................................. C=0.126638017347, total=   0.1s
# [CV] ................................. C=0.228546386413, total=   0.2s
# [CV] C=0.41246263829 .................................................
# [CV] C=0.744380301325 ................................................
# [CV] ................................. C=0.228546386413, total=   0.2s
# [CV] C=0.228546386413 ................................................
# [CV] .................................. C=0.41246263829, total=   0.2s
# [CV] C=0.41246263829 .................................................
# [CV] .................................. C=0.41246263829, total=   0.2s
# [CV] C=0.41246263829 .................................................
# [CV] ................................. C=0.228546386413, total=   0.2s
# [CV] C=1.3433993326 ..................................................
# [CV] .................................. C=0.41246263829, total=   0.1s
# [CV] ................................. C=0.744380301325, total=   0.3s
# [CV] C=0.744380301325 ................................................
# [CV] C=1.3433993326 ..................................................
# [CV] .................................. C=0.41246263829, total=   0.3s
# [CV] C=0.744380301325 ................................................
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:    3.0s
# [CV] ................................. C=0.744380301325, total=   0.2s
# [CV] C=0.744380301325 ................................................
# [CV] ................................... C=1.3433993326, total=   0.3s
# [CV] C=1.3433993326 ..................................................
# [CV] ................................... C=1.3433993326, total=   0.3s
# [CV] C=2.42446201708 .................................................
# [CV] ................................. C=0.744380301325, total=   0.3s
# [CV] C=2.42446201708 .................................................
# [CV] ................................. C=0.744380301325, total=   0.3s
# [CV] C=0.744380301325 ................................................
# [CV] .................................. C=2.42446201708, total=   0.3s
# [CV] C=2.42446201708 .................................................
# [CV] ................................... C=1.3433993326, total=   0.4s
# [CV] C=1.3433993326 ..................................................
# [CV] .................................. C=2.42446201708, total=   0.3s
# [CV] C=2.42446201708 .................................................
# [CV] ................................. C=0.744380301325, total=   0.2s
# [CV] C=4.37547937507 .................................................
# [CV] .................................. C=2.42446201708, total=   0.4s
# [CV] ................................... C=1.3433993326, total=   0.3s
# [CV] C=1.3433993326 ..................................................
# [CV] C=2.42446201708 .................................................
# [CV] .................................. C=2.42446201708, total=   0.3s
# [CV] C=4.37547937507 .................................................
# [CV] .................................. C=4.37547937507, total=   0.4s
# [CV] C=4.37547937507 .................................................
# [CV] ................................... C=1.3433993326, total=   0.3s
# [CV] C=7.8965228685 ..................................................
# [CV] .................................. C=2.42446201708, total=   0.3s
# [CV] C=14.251026703 ..................................................
# [CV] .................................. C=4.37547937507, total=   0.3s
# [CV] C=4.37547937507 .................................................
# [CV] .................................. C=4.37547937507, total=   0.3s
# [CV] C=4.37547937507 .................................................
# [CV] ................................... C=7.8965228685, total=   0.4s
# [CV] C=7.8965228685 ..................................................
# [CV] .................................. C=4.37547937507, total=   0.4s
# [CV] ................................... C=14.251026703, total=   0.5s
# [CV] C=14.251026703 ..................................................
# [CV] C=14.251026703 ..................................................
# [CV] .................................. C=4.37547937507, total=   0.4s
# [CV] C=7.8965228685 ..................................................
# [CV] ................................... C=7.8965228685, total=   0.4s
# [CV] C=7.8965228685 ..................................................
# [CV] ................................... C=7.8965228685, total=   0.3s
# [CV] C=25.7191380906 .................................................
# [CV] ................................... C=7.8965228685, total=   0.3s
# [CV] C=7.8965228685 ..................................................
# [CV] ................................... C=14.251026703, total=   0.7s
# [CV] C=25.7191380906 .................................................
# [CV] ................................... C=14.251026703, total=   0.7s
# [CV] C=14.251026703 ..................................................
# [CV] ................................... C=7.8965228685, total=   0.3s
# [CV] C=46.4158883361 .................................................
# [CV] .................................. C=25.7191380906, total=   0.6s
# [CV] C=25.7191380906 .................................................
# [CV] .................................. C=25.7191380906, total=   0.4s
# [CV] C=25.7191380906 .................................................
# [CV] ................................... C=14.251026703, total=   0.6s
# [CV] C=14.251026703 ..................................................
# [CV] .................................. C=46.4158883361, total=   0.8s
# [CV] C=46.4158883361 .................................................
# [CV] .................................. C=25.7191380906, total=   0.7s
# [CV] C=46.4158883361 .................................................
# [CV] ................................... C=14.251026703, total=   0.4s
# [CV] C=83.7677640068 .................................................
# [CV] .................................. C=25.7191380906, total=   0.7s
# [CV] C=25.7191380906 .................................................
# [CV] .................................. C=46.4158883361, total=   0.6s
# [CV] C=46.4158883361 .................................................
# [CV] .................................. C=46.4158883361, total=   0.4s
# [CV] C=83.7677640068 .................................................
# [CV] .................................. C=25.7191380906, total=   0.7s
# [CV] .................................. C=46.4158883361, total=   0.9s
# [CV] C=151.177507062 .................................................
# [CV] C=46.4158883361 .................................................
# [CV] .................................. C=83.7677640068, total=   1.4s
# [CV] C=83.7677640068 .................................................
# [CV] .................................. C=46.4158883361, total=   0.9s
# [CV] C=151.177507062 .................................................
# [CV] .................................. C=83.7677640068, total=   1.0s
# [CV] C=272.833337649 .................................................
# [CV] .................................. C=151.177507062, total=   1.0s
# [CV] C=151.177507062 .................................................
# [CV] .................................. C=83.7677640068, total=   1.0s
# [CV] C=83.7677640068 .................................................
# [CV] .................................. C=151.177507062, total=   1.0s
# [CV] .................................. C=83.7677640068, total=   0.5s
# [CV] C=151.177507062 .................................................
# [CV] C=83.7677640068 .................................................
# [CV] .................................. C=151.177507062, total=   1.4s
# [CV] C=272.833337649 .................................................
# [CV] .................................. C=272.833337649, total=   1.6s
# [CV] C=272.833337649 .................................................
# [CV] .................................. C=83.7677640068, total=   1.0s
# [CV] C=272.833337649 .................................................
# [CV] .................................. C=151.177507062, total=   1.0s
# [CV] C=151.177507062 .................................................
# [CV] .................................. C=272.833337649, total=   1.2s
# [CV] C=492.388263171 .................................................
# [CV] .................................. C=272.833337649, total=   1.6s
# [CV] C=492.388263171 .................................................
# [CV] .................................. C=272.833337649, total=   1.4s
# [CV] C=272.833337649 .................................................
# [CV] .................................. C=151.177507062, total=   1.6s
# [CV] C=492.388263171 .................................................
# [CV] .................................. C=492.388263171, total=   1.7s
# [CV] C=492.388263171 .................................................
# [CV] .................................. C=492.388263171, total=   1.6s
# [CV] C=492.388263171 .................................................
# [CV] .................................. C=272.833337649, total=   2.0s
# [CV] C=888.623816274 .................................................
# [CV] .................................. C=492.388263171, total=   2.1s
# [CV] C=888.623816274 .................................................
# [CV] .................................. C=492.388263171, total=   1.8s
# [CV] C=888.623816274 .................................................
# [CV] .................................. C=492.388263171, total=   1.6s
# [CV] C=888.623816274 .................................................
# [CV] .................................. C=888.623816274, total=   1.5s
# [CV] C=888.623816274 .................................................
# [CV] .................................. C=888.623816274, total=   1.8s
# [CV] C=1603.71874375 .................................................
# [CV] .................................. C=888.623816274, total=   2.4s
# [CV] C=1603.71874375 .................................................
# [CV] .................................. C=888.623816274, total=   2.1s
# [CV] C=1603.71874375 .................................................
# [CV] .................................. C=888.623816274, total=   2.7s
# [CV] C=1603.71874375 .................................................
# [CV] .................................. C=1603.71874375, total=   2.1s
# [CV] C=1603.71874375 .................................................
# [CV] .................................. C=1603.71874375, total=   1.9s
# [CV] C=2894.26612472 .................................................
# [CV] .................................. C=1603.71874375, total=   2.3s
# [CV] C=2894.26612472 .................................................
# [CV] .................................. C=1603.71874375, total=   2.4s
# [CV] C=2894.26612472 .................................................
# [CV] .................................. C=2894.26612472, total=   2.4s
# [CV] C=2894.26612472 .................................................
# [CV] .................................. C=1603.71874375, total=   3.7s
# [CV] C=2894.26612472 .................................................
# [CV] .................................. C=2894.26612472, total=   2.6s
# [CV] C=5223.34507427 .................................................
# [CV] .................................. C=2894.26612472, total=   2.0s
# [CV] C=5223.34507427 .................................................
# [CV] .................................. C=2894.26612472, total=   2.6s
# [CV] C=5223.34507427 .................................................
# [CV] .................................. C=5223.34507427, total=   1.7s
# [CV] C=5223.34507427 .................................................
# [CV] .................................. C=2894.26612472, total=   3.5s
# [CV] C=5223.34507427 .................................................
# [CV] .................................. C=5223.34507427, total=   3.3s
# [CV] C=9426.68455118 .................................................
# [CV] .................................. C=5223.34507427, total=   2.8s
# [CV] C=9426.68455118 .................................................
# [CV] .................................. C=5223.34507427, total=   2.9s
# [CV] C=9426.68455118 .................................................
# [CV] .................................. C=5223.34507427, total=   3.6s
# [CV] C=9426.68455118 .................................................
# [CV] .................................. C=9426.68455118, total=   2.9s
# [CV] C=9426.68455118 .................................................
# [CV] .................................. C=9426.68455118, total=   3.2s
# [CV] C=17012.5427985 .................................................
# [CV] .................................. C=9426.68455118, total=   4.2s
# [CV] C=17012.5427985 .................................................
# [CV] .................................. C=9426.68455118, total=   3.5s
# [CV] C=17012.5427985 .................................................
# [CV] .................................. C=9426.68455118, total=   3.0s
# [CV] C=17012.5427985 .................................................
# [CV] .................................. C=17012.5427985, total=   3.4s
# [CV] C=17012.5427985 .................................................
# [CV] .................................. C=17012.5427985, total=   5.2s
# [CV] C=30702.9062976 .................................................
# [CV] .................................. C=17012.5427985, total=   3.9s
# [CV] C=30702.9062976 .................................................
# [CV] .................................. C=17012.5427985, total=   5.5s
# [CV] C=30702.9062976 .................................................
# [CV] .................................. C=17012.5427985, total=   2.3s
# [CV] C=30702.9062976 .................................................
# [CV] .................................. C=30702.9062976, total=   2.4s
# [CV] C=30702.9062976 .................................................
# [CV] .................................. C=30702.9062976, total=   2.6s
# [CV] C=55410.2033001 .................................................
# [CV] .................................. C=30702.9062976, total=   5.0s
# [CV] C=55410.2033001 .................................................
# [CV] .................................. C=30702.9062976, total=   4.4s
# [CV] C=55410.2033001 .................................................
# [CV] .................................. C=30702.9062976, total=   4.2s
# [CV] C=55410.2033001 .................................................
# [CV] .................................. C=55410.2033001, total=   4.0s
# [CV] C=55410.2033001 .................................................
# [CV] .................................. C=55410.2033001, total=   4.5s
# [CV] C=100000.0 ......................................................
# [CV] .................................. C=55410.2033001, total=   4.4s
# [CV] C=100000.0 ......................................................
# [CV] .................................. C=55410.2033001, total=   4.6s
# [CV] C=100000.0 ......................................................
# [CV] .................................. C=55410.2033001, total=   5.5s
# [CV] C=100000.0 ......................................................
# [CV] ....................................... C=100000.0, total=   3.0s
# [CV] C=100000.0 ......................................................
# [CV] ....................................... C=100000.0, total=   3.9s
# [CV] ....................................... C=100000.0, total=   4.8s
# [CV] ....................................... C=100000.0, total=   3.8s
# [CV] ....................................... C=100000.0, total=   3.7s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:   52.7s finished
# /home/pace/Documents/data_science/project-pace-mourad/adrian/src/plots.py:30: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if train_scores_std != None and val_scores_std != None:
# Best ['C'] = {'C': 0.4124626382901348} with score : 0.724
# Execution time : 54.020185470581055 seconds
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': array([  1.00000e-05,   1.80472e-05,   3.25702e-05,   5.87802e-05,
#          1.06082e-04,   1.91448e-04,   3.45511e-04,   6.23551e-04,
#          1.12534e-03,   2.03092e-03,   3.66524e-03,   6.61474e-03,
#          1.19378e-02,   2.15443e-02,   3.88816e-02,   7.01704e-02,
#          1.2663...,   5.22335e+03,   9.42668e+03,
#          1.70125e+04,   3.07029e+04,   5.54102e+04,   1.00000e+05])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=2)

# %% [markdown]
# 5000, just counts : Best ['C'] = {'C': 0.0020309176209047349} with score : 0.61625
# Execution time : 3.594806671142578 seconds

# %% [markdown]
# ALL FEATURES 5000 Best ['C'] = {'C': 0.4124626382901348} with score : 0.724
# Execution time : 63.45723795890808 seconds
# Out[123]:

# %% [markdown]
# only words 5000 Best ['C'] = {'C': 0.74438030132516808} with score : 0.7225
# Execution time : 32.86425304412842 seconds

# %%
parameter_search(LogisticRegression(),
                {'C':np.arange(0.05,5,0.05)},
                X_train,
                y_train, save_file=save_location+'/log_reg_more_acc.png')
# Out:
# Fitting 5 folds for each of 99 candidates, totalling 495 fits
# [CV] C=0.05 ..........................................................
# [CV] C=0.05 ..........................................................
# [CV] C=0.05 ..........................................................
# [CV] C=0.05 ..........................................................
# [CV] ........................................... C=0.05, total=   0.2s
# [CV] C=0.05 ..........................................................
# [CV] ........................................... C=0.05, total=   0.2s
# [CV] C=0.1 ...........................................................
# [CV] ........................................... C=0.05, total=   0.3s
# [CV] ........................................... C=0.05, total=   0.3s
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] ........................................... C=0.05, total=   0.2s
# [CV] ............................................ C=0.1, total=   0.2s
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] ............................................ C=0.1, total=   0.2s
# [CV] C=0.15 ..........................................................
# [CV] ............................................ C=0.1, total=   0.2s
# [CV] ............................................ C=0.1, total=   0.1s
# [CV] C=0.15 ..........................................................
# [CV] C=0.15 ..........................................................
# [CV] ............................................ C=0.1, total=   0.2s
# [CV] C=0.15 ..........................................................
# [CV] ........................................... C=0.15, total=   0.2s
# [CV] C=0.15 ..........................................................
# [CV] ........................................... C=0.15, total=   0.2s
# [CV] C=0.2 ...........................................................
# [CV] ........................................... C=0.15, total=   0.2s
# [CV] C=0.2 ...........................................................
# [CV] ........................................... C=0.15, total=   0.3s
# [CV] C=0.2 ...........................................................
# [CV] ............................................ C=0.2, total=   0.2s
# [CV] C=0.2 ...........................................................
# [CV] ........................................... C=0.15, total=   0.3s
# [CV] C=0.2 ...........................................................
# [CV] ............................................ C=0.2, total=   0.2s
# [CV] C=0.25 ..........................................................
# [CV] ............................................ C=0.2, total=   0.2s
# [CV] C=0.25 ..........................................................
# [CV] ............................................ C=0.2, total=   0.2s
# [CV] C=0.25 ..........................................................
# [CV] ............................................ C=0.2, total=   0.2s
# [CV] ........................................... C=0.25, total=   0.2s
# [CV] C=0.25 ..........................................................
# [CV] C=0.25 ..........................................................
# [CV] ........................................... C=0.25, total=   0.2s
# [CV] C=0.3 ...........................................................
# [CV] ........................................... C=0.25, total=   0.2s
# [CV] C=0.3 ...........................................................
# [CV] ........................................... C=0.25, total=   0.1s
# [CV] C=0.3 ...........................................................
# [CV] ........................................... C=0.25, total=   0.2s
# [CV] C=0.3 ...........................................................
# [CV] ............................................ C=0.3, total=   0.2s
# [CV] C=0.3 ...........................................................
# [CV] ............................................ C=0.3, total=   0.2s
# [CV] ............................................ C=0.3, total=   0.1s
# [CV] C=0.35 ..........................................................
# [CV] C=0.35 ..........................................................
# [CV] ............................................ C=0.3, total=   0.2s
# [CV] C=0.35 ..........................................................
# [CV] ............................................ C=0.3, total=   0.2s
# [CV] C=0.35 ..........................................................
# [CV] ........................................... C=0.35, total=   0.2s
# [CV] C=0.35 ..........................................................
# [CV] ........................................... C=0.35, total=   0.3s
# [CV] C=0.4 ...........................................................
# [CV] ........................................... C=0.35, total=   0.3s
# [CV] C=0.4 ...........................................................
# [CV] ........................................... C=0.35, total=   0.2s
# [CV] C=0.4 ...........................................................
# [CV] ........................................... C=0.35, total=   0.2s
# [CV] C=0.4 ...........................................................
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    2.1s
# [CV] ............................................ C=0.4, total=   0.3s
# [CV] C=0.4 ...........................................................
# [CV] ............................................ C=0.4, total=   0.2s
# [CV] ............................................ C=0.4, total=   0.3s
# [CV] C=0.45 ..........................................................
# [CV] C=0.45 ..........................................................
# [CV] ............................................ C=0.4, total=   0.3s
# [CV] C=0.45 ..........................................................
# [CV] ............................................ C=0.4, total=   0.2s
# [CV] C=0.45 ..........................................................
# [CV] ........................................... C=0.45, total=   0.2s
# [CV] C=0.45 ..........................................................
# [CV] ........................................... C=0.45, total=   0.3s
# [CV] C=0.5 ...........................................................
# [CV] ........................................... C=0.45, total=   0.2s
# [CV] C=0.5 ...........................................................
# [CV] ........................................... C=0.45, total=   0.3s
# [CV] C=0.5 ...........................................................
# [CV] ........................................... C=0.45, total=   0.2s
# [CV] C=0.5 ...........................................................
# [CV] ............................................ C=0.5, total=   0.2s
# [CV] ............................................ C=0.5, total=   0.2s
# [CV] C=0.5 ...........................................................
# [CV] C=0.55 ..........................................................
# [CV] ............................................ C=0.5, total=   0.3s
# [CV] C=0.55 ..........................................................
# [CV] ............................................ C=0.5, total=   0.2s
# [CV] ............................................ C=0.5, total=   0.3s
# [CV] C=0.55 ..........................................................
# [CV] C=0.55 ..........................................................
# [CV] ........................................... C=0.55, total=   0.3s
# [CV] C=0.55 ..........................................................
# [CV] ........................................... C=0.55, total=   0.1s
# [CV] C=0.6 ...........................................................
# [CV] ........................................... C=0.55, total=   0.2s
# [CV] ........................................... C=0.55, total=   0.3s
# [CV] C=0.6 ...........................................................
# [CV] C=0.6 ...........................................................
# [CV] ........................................... C=0.55, total=   0.2s
# [CV] C=0.6 ...........................................................
# [CV] ............................................ C=0.6, total=   0.2s
# [CV] C=0.6 ...........................................................
# [CV] ............................................ C=0.6, total=   0.1s
# [CV] C=0.65 ..........................................................
# [CV] ............................................ C=0.6, total=   0.3s
# [CV] C=0.65 ..........................................................
# [CV] ............................................ C=0.6, total=   0.3s
# [CV] C=0.65 ..........................................................
# [CV] ............................................ C=0.6, total=   0.2s
# [CV] C=0.65 ..........................................................
# [CV] ........................................... C=0.65, total=   0.2s
# [CV] C=0.65 ..........................................................
# [CV] ........................................... C=0.65, total=   0.2s
# [CV] C=0.7 ...........................................................
# [CV] ........................................... C=0.65, total=   0.2s
# [CV] C=0.7 ...........................................................
# [CV] ........................................... C=0.65, total=   0.2s
# [CV] C=0.7 ...........................................................
# [CV] ........................................... C=0.65, total=   0.2s
# [CV] C=0.7 ...........................................................
# [CV] ............................................ C=0.7, total=   0.2s
# [CV] C=0.7 ...........................................................
# [CV] ............................................ C=0.7, total=   0.2s
# [CV] C=0.75 ..........................................................
# [CV] ............................................ C=0.7, total=   0.2s
# [CV] C=0.75 ..........................................................
# [CV] ............................................ C=0.7, total=   0.3s
# [CV] C=0.75 ..........................................................
# [CV] ............................................ C=0.7, total=   0.3s
# [CV] C=0.75 ..........................................................
# [CV] ........................................... C=0.75, total=   0.2s
# [CV] C=0.75 ..........................................................
# [CV] ........................................... C=0.75, total=   0.2s
# [CV] C=0.8 ...........................................................
# [CV] ........................................... C=0.75, total=   0.2s
# [CV] ........................................... C=0.75, total=   0.2s
# [CV] C=0.8 ...........................................................
# [CV] C=0.8 ...........................................................
# [CV] ............................................ C=0.8, total=   0.2s
# [CV] ........................................... C=0.75, total=   0.2s
# [CV] C=0.8 ...........................................................
# [CV] C=0.8 ...........................................................
# [CV] ............................................ C=0.8, total=   0.2s
# [CV] C=0.85 ..........................................................
# [CV] ............................................ C=0.8, total=   0.3s
# [CV] C=0.85 ..........................................................
# [CV] ............................................ C=0.8, total=   0.2s
# [CV] C=0.85 ..........................................................
# [CV] ............................................ C=0.8, total=   0.3s
# [CV] C=0.85 ..........................................................
# [CV] ........................................... C=0.85, total=   0.3s
# [CV] C=0.85 ..........................................................
# [CV] ........................................... C=0.85, total=   0.2s
# [CV] ........................................... C=0.85, total=   0.3s
# [CV] C=0.9 ...........................................................
# [CV] C=0.9 ...........................................................
# [CV] ........................................... C=0.85, total=   0.2s
# [CV] C=0.9 ...........................................................
# [CV] ........................................... C=0.85, total=   0.2s
# [CV] C=0.9 ...........................................................
# [CV] ............................................ C=0.9, total=   0.2s
# [CV] C=0.9 ...........................................................
# [CV] ............................................ C=0.9, total=   0.3s
# [CV] C=0.95 ..........................................................
# [CV] ............................................ C=0.9, total=   0.2s
# [CV] C=0.95 ..........................................................
# [CV] ............................................ C=0.9, total=   0.2s
# [CV] C=0.95 ..........................................................
# [CV] ............................................ C=0.9, total=   0.2s
# [CV] C=0.95 ..........................................................
# [CV] ........................................... C=0.95, total=   0.2s
# [CV] ........................................... C=0.95, total=   0.2s
# [CV] C=1.0 ...........................................................
# [CV] C=0.95 ..........................................................
# [CV] ........................................... C=0.95, total=   0.1s
# [CV] C=1.0 ...........................................................
# [CV] ........................................... C=0.95, total=   0.2s
# [CV] C=1.0 ...........................................................
# [CV] ........................................... C=0.95, total=   0.3s
# [CV] C=1.0 ...........................................................
# [CV] ............................................ C=1.0, total=   0.4s
# [CV] ............................................ C=1.0, total=   0.3s
# [CV] C=1.0 ...........................................................
# [CV] C=1.05 ..........................................................
# [CV] ............................................ C=1.0, total=   0.3s
# [CV] C=1.05 ..........................................................
# [CV] ............................................ C=1.0, total=   0.2s
# [CV] C=1.05 ..........................................................
# [CV] ............................................ C=1.0, total=   0.3s
# [CV] C=1.05 ..........................................................
# [CV] ........................................... C=1.05, total=   0.2s
# [CV] C=1.05 ..........................................................
# [CV] ........................................... C=1.05, total=   0.2s
# [CV] C=1.1 ...........................................................
# [CV] ........................................... C=1.05, total=   0.2s
# [CV] C=1.1 ...........................................................
# [CV] ........................................... C=1.05, total=   0.3s
# [CV] C=1.1 ...........................................................
# [CV] ............................................ C=1.1, total=   0.2s
# [CV] C=1.1 ...........................................................
# [CV] ........................................... C=1.05, total=   0.3s
# [CV] C=1.1 ...........................................................
# [CV] ............................................ C=1.1, total=   0.3s
# [CV] C=1.15 ..........................................................
# [CV] ............................................ C=1.1, total=   0.2s
# [CV] C=1.15 ..........................................................
# [CV] ............................................ C=1.1, total=   0.2s
# [CV] C=1.15 ..........................................................
# [CV] ............................................ C=1.1, total=   0.3s
# [CV] C=1.15 ..........................................................
# [CV] ........................................... C=1.15, total=   0.3s
# [CV] C=1.15 ..........................................................
# [CV] ........................................... C=1.15, total=   0.2s
# [CV] C=1.2 ...........................................................
# [CV] ........................................... C=1.15, total=   0.4s
# [CV] C=1.2 ...........................................................
# [CV] ............................................ C=1.2, total=   0.2s
# [CV] C=1.2 ...........................................................
# [CV] ........................................... C=1.15, total=   0.4s
# [CV] C=1.2 ...........................................................
# [CV] ............................................ C=1.2, total=   0.2s
# [CV] ........................................... C=1.15, total=   0.3s
# [CV] C=1.25 ..........................................................
# [CV] C=1.2 ...........................................................
# [CV] ............................................ C=1.2, total=   0.2s
# [CV] ............................................ C=1.2, total=   0.3s
# [CV] C=1.25 ..........................................................
# [CV] C=1.25 ..........................................................
# [CV] ............................................ C=1.2, total=   0.2s
# [CV] C=1.25 ..........................................................
# [CV] ........................................... C=1.25, total=   0.3s
# [CV] C=1.25 ..........................................................
# [CV] ........................................... C=1.25, total=   0.2s
# [CV] C=1.3 ...........................................................
# [CV] ........................................... C=1.25, total=   0.2s
# [CV] C=1.3 ...........................................................
# [CV] ........................................... C=1.25, total=   0.3s
# [CV] ........................................... C=1.25, total=   0.2s
# [CV] C=1.3 ...........................................................
# [CV] C=1.3 ...........................................................
# [CV] ............................................ C=1.3, total=   0.1s
# [CV] ............................................ C=1.3, total=   0.3s
# [CV] C=1.35 ..........................................................
# [CV] C=1.3 ...........................................................
# [CV] ............................................ C=1.3, total=   0.3s
# [CV] ............................................ C=1.3, total=   0.3s
# [CV] C=1.35 ..........................................................
# [CV] C=1.35 ..........................................................
# [CV] ........................................... C=1.35, total=   0.2s
# [CV] C=1.35 ..........................................................
# [CV] ............................................ C=1.3, total=   0.3s
# [CV] C=1.35 ..........................................................
# [CV] ........................................... C=1.35, total=   0.2s
# [CV] C=1.4 ...........................................................
# [CV] ........................................... C=1.35, total=   0.2s
# [CV] C=1.4 ...........................................................
# [CV] ........................................... C=1.35, total=   0.3s
# [CV] C=1.4 ...........................................................
# [CV] ........................................... C=1.35, total=   0.3s
# [CV] C=1.4 ...........................................................
# [CV] ............................................ C=1.4, total=   0.2s
# [CV] ............................................ C=1.4, total=   0.2s
# [CV] C=1.4 ...........................................................
# [CV] C=1.45 ..........................................................
# [CV] ............................................ C=1.4, total=   0.3s
# [CV] C=1.45 ..........................................................
# [CV] ............................................ C=1.4, total=   0.3s
# [CV] C=1.45 ..........................................................
# [CV] ........................................... C=1.45, total=   0.3s
# [CV] ............................................ C=1.4, total=   0.4s
# [CV] C=1.45 ..........................................................
# [CV] C=1.45 ..........................................................
# [CV] ........................................... C=1.45, total=   0.3s
# [CV] C=1.5 ...........................................................
# [CV] ........................................... C=1.45, total=   0.2s
# [CV] C=1.5 ...........................................................
# [CV] ........................................... C=1.45, total=   0.4s
# [CV] C=1.5 ...........................................................
# [CV] ........................................... C=1.45, total=   0.3s
# [CV] C=1.5 ...........................................................
# [CV] ............................................ C=1.5, total=   0.3s
# [CV] C=1.5 ...........................................................
# [CV] ............................................ C=1.5, total=   0.2s
# [CV] ............................................ C=1.5, total=   0.3s
# [CV] C=1.55 ..........................................................
# [CV] C=1.55 ..........................................................
# [CV] ............................................ C=1.5, total=   0.4s
# [CV] C=1.55 ..........................................................
# [CV] ............................................ C=1.5, total=   0.4s
# [CV] C=1.55 ..........................................................
# [CV] ........................................... C=1.55, total=   0.3s
# [CV] C=1.55 ..........................................................
# [CV] ........................................... C=1.55, total=   0.4s
# [CV] C=1.6 ...........................................................
# [CV] ........................................... C=1.55, total=   0.2s
# [CV] C=1.6 ...........................................................
# [CV] ........................................... C=1.55, total=   0.3s
# [CV] C=1.6 ...........................................................
# [CV] ............................................ C=1.6, total=   0.2s
# [CV] C=1.6 ...........................................................
# [CV] ........................................... C=1.55, total=   0.3s
# [CV] C=1.6 ...........................................................
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   10.6s
# [CV] ............................................ C=1.6, total=   0.3s
# [CV] ............................................ C=1.6, total=   0.3s
# [CV] C=1.65 ..........................................................
# [CV] C=1.65 ..........................................................
# [CV] ............................................ C=1.6, total=   0.3s
# [CV] C=1.65 ..........................................................
# [CV] ............................................ C=1.6, total=   0.3s
# [CV] C=1.65 ..........................................................
# [CV] ........................................... C=1.65, total=   0.2s
# [CV] C=1.65 ..........................................................
# [CV] ........................................... C=1.65, total=   0.3s
# [CV] C=1.7 ...........................................................
# [CV] ........................................... C=1.65, total=   0.2s
# [CV] C=1.7 ...........................................................
# [CV] ........................................... C=1.65, total=   0.3s
# [CV] C=1.7 ...........................................................
# [CV] ........................................... C=1.65, total=   0.3s
# [CV] C=1.7 ...........................................................
# [CV] ............................................ C=1.7, total=   0.3s
# [CV] ............................................ C=1.7, total=   0.3s
# [CV] C=1.7 ...........................................................
# [CV] C=1.75 ..........................................................
# [CV] ............................................ C=1.7, total=   0.4s
# [CV] C=1.75 ..........................................................
# [CV] ............................................ C=1.7, total=   0.4s
# [CV] ........................................... C=1.75, total=   0.3s
# [CV] ............................................ C=1.7, total=   0.3s
# [CV] C=1.75 ..........................................................
# [CV] C=1.75 ..........................................................
# [CV] C=1.75 ..........................................................
# [CV] ........................................... C=1.75, total=   0.2s
# [CV] C=1.8 ...........................................................
# [CV] ........................................... C=1.75, total=   0.2s
# [CV] C=1.8 ...........................................................
# [CV] ........................................... C=1.75, total=   0.4s
# [CV] C=1.8 ...........................................................
# [CV] ........................................... C=1.75, total=   0.5s
# [CV] C=1.8 ...........................................................
# [CV] ............................................ C=1.8, total=   0.4s
# [CV] C=1.8 ...........................................................
# [CV] ............................................ C=1.8, total=   0.4s
# [CV] C=1.85 ..........................................................
# [CV] ............................................ C=1.8, total=   0.3s
# [CV] C=1.85 ..........................................................
# [CV] ............................................ C=1.8, total=   0.3s
# [CV] C=1.85 ..........................................................
# [CV] ............................................ C=1.8, total=   0.4s
# [CV] C=1.85 ..........................................................
# [CV] ........................................... C=1.85, total=   0.3s
# [CV] C=1.85 ..........................................................
# [CV] ........................................... C=1.85, total=   0.3s
# [CV] ........................................... C=1.85, total=   0.3s
# [CV] C=1.9 ...........................................................
# [CV] C=1.9 ...........................................................
# [CV] ........................................... C=1.85, total=   0.3s
# [CV] C=1.9 ...........................................................
# [CV] ........................................... C=1.85, total=   0.3s
# [CV] C=1.9 ...........................................................
# [CV] ............................................ C=1.9, total=   0.3s
# [CV] C=1.9 ...........................................................
# [CV] ............................................ C=1.9, total=   0.3s
# [CV] ............................................ C=1.9, total=   0.3s
# [CV] C=1.95 ..........................................................
# [CV] C=1.95 ..........................................................
# [CV] ............................................ C=1.9, total=   0.3s
# [CV] C=1.95 ..........................................................
# [CV] ............................................ C=1.9, total=   0.3s
# [CV] C=1.95 ..........................................................
# [CV] ........................................... C=1.95, total=   0.3s
# [CV] C=1.95 ..........................................................
# [CV] ........................................... C=1.95, total=   0.4s
# [CV] C=2.0 ...........................................................
# [CV] ........................................... C=1.95, total=   0.3s
# [CV] ........................................... C=1.95, total=   0.4s
# [CV] C=2.0 ...........................................................
# [CV] C=2.0 ...........................................................
# [CV] ........................................... C=1.95, total=   0.3s
# [CV] C=2.0 ...........................................................
# [CV] ............................................ C=2.0, total=   0.4s
# [CV] ............................................ C=2.0, total=   0.3s
# [CV] C=2.0 ...........................................................
# [CV] ............................................ C=2.0, total=   0.3s
# [CV] C=2.05 ..........................................................
# [CV] C=2.05 ..........................................................
# [CV] ............................................ C=2.0, total=   0.4s
# [CV] C=2.05 ..........................................................
# [CV] ........................................... C=2.05, total=   0.3s
# [CV] C=2.05 ..........................................................
# [CV] ........................................... C=2.05, total=   0.2s
# [CV] C=2.05 ..........................................................
# [CV] ............................................ C=2.0, total=   0.3s
# [CV] C=2.1 ...........................................................
# [CV] ........................................... C=2.05, total=   0.3s
# [CV] C=2.1 ...........................................................
# [CV] ........................................... C=2.05, total=   0.5s
# [CV] C=2.1 ...........................................................
# [CV] ............................................ C=2.1, total=   0.4s
# [CV] C=2.1 ...........................................................
# [CV] ........................................... C=2.05, total=   0.5s
# [CV] C=2.1 ...........................................................
# [CV] ............................................ C=2.1, total=   0.3s
# [CV] ............................................ C=2.1, total=   0.4s
# [CV] C=2.15 ..........................................................
# [CV] C=2.15 ..........................................................
# [CV] ............................................ C=2.1, total=   0.3s
# [CV] C=2.15 ..........................................................
# [CV] ............................................ C=2.1, total=   0.4s
# [CV] C=2.15 ..........................................................
# [CV] ........................................... C=2.15, total=   0.2s
# [CV] C=2.15 ..........................................................
# [CV] ........................................... C=2.15, total=   0.4s
# [CV] ........................................... C=2.15, total=   0.4s
# [CV] C=2.2 ...........................................................
# [CV] C=2.2 ...........................................................
# [CV] ........................................... C=2.15, total=   0.4s
# [CV] C=2.2 ...........................................................
# [CV] ........................................... C=2.15, total=   0.3s
# [CV] C=2.2 ...........................................................
# [CV] ............................................ C=2.2, total=   0.3s
# [CV] C=2.2 ...........................................................
# [CV] ............................................ C=2.2, total=   0.5s
# [CV] ............................................ C=2.2, total=   0.2s
# [CV] C=2.25 ..........................................................
# [CV] C=2.25 ..........................................................
# [CV] ............................................ C=2.2, total=   0.4s
# [CV] C=2.25 ..........................................................
# [CV] ........................................... C=2.25, total=   0.4s
# [CV] C=2.25 ..........................................................
# [CV] ............................................ C=2.2, total=   0.5s
# [CV] C=2.25 ..........................................................
# [CV] ........................................... C=2.25, total=   0.6s
# [CV] C=2.3 ...........................................................
# [CV] ........................................... C=2.25, total=   0.7s
# [CV] C=2.3 ...........................................................
# [CV] ........................................... C=2.25, total=   0.7s
# [CV] C=2.3 ...........................................................
# [CV] ............................................ C=2.3, total=   0.6s
# [CV] C=2.3 ...........................................................
# [CV] ........................................... C=2.25, total=   0.8s
# [CV] C=2.3 ...........................................................
# [CV] ............................................ C=2.3, total=   0.8s
# [CV] C=2.35 ..........................................................
# [CV] ............................................ C=2.3, total=   0.5s
# [CV] C=2.35 ..........................................................
# [CV] ............................................ C=2.3, total=   0.6s
# [CV] C=2.35 ..........................................................
# [CV] ............................................ C=2.3, total=   0.5s
# [CV] C=2.35 ..........................................................
# [CV] ........................................... C=2.35, total=   0.5s
# [CV] C=2.35 ..........................................................
# [CV] ........................................... C=2.35, total=   0.5s
# [CV] C=2.4 ...........................................................
# [CV] ........................................... C=2.35, total=   0.5s
# [CV] C=2.4 ...........................................................
# [CV] ........................................... C=2.35, total=   0.5s
# [CV] C=2.4 ...........................................................
# [CV] ........................................... C=2.35, total=   0.4s
# [CV] C=2.4 ...........................................................
# [CV] ............................................ C=2.4, total=   0.4s
# [CV] C=2.4 ...........................................................
# [CV] ............................................ C=2.4, total=   0.3s
# [CV] C=2.45 ..........................................................
# [CV] ............................................ C=2.4, total=   0.4s
# [CV] C=2.45 ..........................................................
# [CV] ............................................ C=2.4, total=   0.3s
# [CV] C=2.45 ..........................................................
# [CV] ........................................... C=2.45, total=   0.4s
# [CV] C=2.45 ..........................................................
# [CV] ............................................ C=2.4, total=   0.5s
# [CV] C=2.45 ..........................................................
# [CV] ........................................... C=2.45, total=   0.4s
# [CV] C=2.5 ...........................................................
# [CV] ........................................... C=2.45, total=   0.5s
# [CV] C=2.5 ...........................................................
# [CV] ........................................... C=2.45, total=   0.4s
# [CV] ............................................ C=2.5, total=   0.4s
# [CV] C=2.5 ...........................................................
# [CV] C=2.5 ...........................................................
# [CV] ............................................ C=2.5, total=   0.4s
# [CV] C=2.5 ...........................................................
# [CV] ........................................... C=2.45, total=   0.6s
# [CV] C=2.55 ..........................................................
# [CV] ............................................ C=2.5, total=   0.4s
# [CV] C=2.55 ..........................................................
# [CV] ............................................ C=2.5, total=   0.4s
# [CV] C=2.55 ..........................................................
# [CV] ............................................ C=2.5, total=   0.3s
# [CV] C=2.55 ..........................................................
# [CV] ........................................... C=2.55, total=   0.5s
# [CV] C=2.55 ..........................................................
# [CV] ........................................... C=2.55, total=   0.4s
# [CV] ........................................... C=2.55, total=   0.3s
# [CV] C=2.6 ...........................................................
# [CV] C=2.6 ...........................................................
# [CV] ........................................... C=2.55, total=   0.4s
# [CV] C=2.6 ...........................................................
# [CV] ............................................ C=2.6, total=   0.3s
# [CV] C=2.6 ...........................................................
# [CV] ............................................ C=2.6, total=   0.3s
# [CV] C=2.6 ...........................................................
# [CV] ............................................ C=2.6, total=   0.3s
# [CV] ........................................... C=2.55, total=   0.5s
# [CV] C=2.65 ..........................................................
# [CV] C=2.65 ..........................................................
# [CV] ............................................ C=2.6, total=   0.3s
# [CV] C=2.65 ..........................................................
# [CV] ............................................ C=2.6, total=   0.4s
# [CV] C=2.65 ..........................................................
# [CV] ........................................... C=2.65, total=   0.3s
# [CV] C=2.65 ..........................................................
# [CV] ........................................... C=2.65, total=   0.4s
# [CV] C=2.7 ...........................................................
# [CV] ........................................... C=2.65, total=   0.2s
# [CV] C=2.7 ...........................................................
# [CV] ........................................... C=2.65, total=   0.4s
# [CV] C=2.7 ...........................................................
# [CV] ........................................... C=2.65, total=   0.4s
# [CV] C=2.7 ...........................................................
# [CV] ............................................ C=2.7, total=   0.3s
# [CV] C=2.7 ...........................................................
# [CV] ............................................ C=2.7, total=   0.5s
# [CV] C=2.75 ..........................................................
# [CV] ............................................ C=2.7, total=   0.2s
# [CV] C=2.75 ..........................................................
# [CV] ............................................ C=2.7, total=   0.4s
# [CV] C=2.75 ..........................................................
# [CV] ............................................ C=2.7, total=   0.4s
# [CV] C=2.75 ..........................................................
# [CV] ........................................... C=2.75, total=   0.3s
# [CV] C=2.75 ..........................................................
# [CV] ........................................... C=2.75, total=   0.4s
# [CV] C=2.8 ...........................................................
# [CV] ........................................... C=2.75, total=   0.4s
# [CV] ........................................... C=2.75, total=   0.4s
# [CV] C=2.8 ...........................................................
# [CV] C=2.8 ...........................................................
# [CV] ........................................... C=2.75, total=   0.3s
# [CV] C=2.8 ...........................................................
# [CV] ............................................ C=2.8, total=   0.3s
# [CV] C=2.8 ...........................................................
# [CV] ............................................ C=2.8, total=   0.5s
# [CV] ............................................ C=2.8, total=   0.4s
# [CV] C=2.85 ..........................................................
# [CV] ............................................ C=2.8, total=   0.5s
# [CV] C=2.85 ..........................................................
# [CV] C=2.85 ..........................................................
# [CV] ............................................ C=2.8, total=   0.4s
# [CV] C=2.85 ..........................................................
# [CV] ........................................... C=2.85, total=   0.3s
# [CV] C=2.85 ..........................................................
# [CV] ........................................... C=2.85, total=   0.4s
# [CV] C=2.9 ...........................................................
# [CV] ........................................... C=2.85, total=   0.4s
# [CV] C=2.9 ...........................................................
# [CV] ........................................... C=2.85, total=   0.5s
# [CV] C=2.9 ...........................................................
# [CV] ............................................ C=2.9, total=   0.4s
# [CV] ........................................... C=2.85, total=   0.5s
# [CV] C=2.9 ...........................................................
# [CV] C=2.9 ...........................................................
# [CV] ............................................ C=2.9, total=   0.5s
# [CV] C=2.95 ..........................................................
# [CV] ............................................ C=2.9, total=   0.5s
# [CV] C=2.95 ..........................................................
# [CV] ............................................ C=2.9, total=   0.4s
# [CV] C=2.95 ..........................................................
# [CV] ............................................ C=2.9, total=   0.5s
# [CV] C=2.95 ..........................................................
# [CV] ........................................... C=2.95, total=   0.4s
# [CV] C=2.95 ..........................................................
# [CV] ........................................... C=2.95, total=   0.4s
# [CV] C=3.0 ...........................................................
# [CV] ........................................... C=2.95, total=   0.4s
# [CV] C=3.0 ...........................................................
# [CV] ............................................ C=3.0, total=   0.4s
# [CV] C=3.0 ...........................................................
# [CV] ........................................... C=2.95, total=   0.7s
# [CV] C=3.0 ...........................................................
# [CV] ........................................... C=2.95, total=   0.7s
# [CV] C=3.0 ...........................................................
# [CV] ............................................ C=3.0, total=   0.9s
# [CV] C=3.05 ..........................................................
# [CV] ............................................ C=3.0, total=   0.9s
# [CV] ............................................ C=3.0, total=   0.7s
# [CV] C=3.05 ..........................................................
# [CV] C=3.05 ..........................................................
# [CV] ............................................ C=3.0, total=   0.8s
# [CV] C=3.05 ..........................................................
# [CV] ........................................... C=3.05, total=   0.6s
# [CV] C=3.05 ..........................................................
# [CV] ........................................... C=3.05, total=   0.3s
# [CV] C=3.1 ...........................................................
# [CV] ........................................... C=3.05, total=   0.4s
# [CV] C=3.1 ...........................................................
# [CV] ........................................... C=3.05, total=   0.4s
# [CV] C=3.1 ...........................................................
# [CV] ........................................... C=3.05, total=   0.4s
# [CV] C=3.1 ...........................................................
# [CV] ............................................ C=3.1, total=   0.4s
# [CV] C=3.1 ...........................................................
# [CV] ............................................ C=3.1, total=   0.4s
# [CV] ............................................ C=3.1, total=   0.3s
# [CV] C=3.15 ..........................................................
# [CV] C=3.15 ..........................................................
# [CV] ............................................ C=3.1, total=   0.5s
# [CV] C=3.15 ..........................................................
# [CV] ............................................ C=3.1, total=   0.6s
# [CV] ........................................... C=3.15, total=   0.6s
# [CV] C=3.15 ..........................................................
# [CV] C=3.15 ..........................................................
# [CV] ........................................... C=3.15, total=   0.7s
# [CV] C=3.2 ...........................................................
# [CV] ........................................... C=3.15, total=   0.5s
# [CV] C=3.2 ...........................................................
# [CV] ........................................... C=3.15, total=   0.5s
# [CV] C=3.2 ...........................................................
# [CV] ............................................ C=3.2, total=   0.5s
# [CV] C=3.2 ...........................................................
# [CV] ........................................... C=3.15, total=   0.7s
# [CV] C=3.2 ...........................................................
# [CV] ............................................ C=3.2, total=   0.6s
# [CV] C=3.25 ..........................................................
# [CV] ............................................ C=3.2, total=   0.6s
# [CV] C=3.25 ..........................................................
# [CV] ............................................ C=3.2, total=   0.5s
# [CV] C=3.25 ..........................................................
# [CV] ............................................ C=3.2, total=   0.6s
# [CV] C=3.25 ..........................................................
# [CV] ........................................... C=3.25, total=   0.5s
# [CV] C=3.25 ..........................................................
# [CV] ........................................... C=3.25, total=   0.6s
# [CV] C=3.3 ...........................................................
# [CV] ........................................... C=3.25, total=   0.8s
# [CV] C=3.3 ...........................................................
# [CV] ........................................... C=3.25, total=   0.7s
# [CV] C=3.3 ...........................................................
# [CV] ........................................... C=3.25, total=   0.5s
# [CV] C=3.3 ...........................................................
# [CV] ............................................ C=3.3, total=   0.5s
# [CV] C=3.3 ...........................................................
# [CV] ............................................ C=3.3, total=   0.7s
# [CV] C=3.35 ..........................................................
# [CV] ............................................ C=3.3, total=   0.5s
# [CV] C=3.35 ..........................................................
# [CV] ............................................ C=3.3, total=   0.5s
# [CV] C=3.35 ..........................................................
# [CV] ............................................ C=3.3, total=   0.6s
# [CV] C=3.35 ..........................................................
# [CV] ........................................... C=3.35, total=   0.4s
# [CV] C=3.35 ..........................................................
# [CV] ........................................... C=3.35, total=   0.5s
# [CV] C=3.4 ...........................................................
# [CV] ........................................... C=3.35, total=   0.8s
# [CV] C=3.4 ...........................................................
# [CV] ........................................... C=3.35, total=   0.8s
# [CV] ............................................ C=3.4, total=   0.4s
# [CV] C=3.4 ...........................................................
# ...
# [CV] C=3.95 ..........................................................
# [CV] ............................................ C=3.9, total=   0.5s
# [CV] C=3.95 ..........................................................
# [CV] ............................................ C=3.9, total=   0.6s
# [CV] C=3.95 ..........................................................
# [CV] ........................................... C=3.95, total=   0.6s
# [CV] C=3.95 ..........................................................
# [CV] ........................................... C=3.95, total=   0.5s
# [CV] ........................................... C=3.95, total=   0.6s
# [CV] C=4.0 ...........................................................
# [CV] C=4.0 ...........................................................
# [CV] ........................................... C=3.95, total=   0.4s
# [CV] C=4.0 ...........................................................
# [CV] ............................................ C=4.0, total=   0.5s
# [CV] C=4.0 ...........................................................
# [CV] ........................................... C=3.95, total=   0.7s
# [CV] ............................................ C=4.0, total=   0.7s
# [CV] C=4.0 ...........................................................
# [CV] ............................................ C=4.0, total=   0.5s
# [CV] C=4.05 ..........................................................
# [CV] C=4.05 ..........................................................
# [CV] ............................................ C=4.0, total=   0.6s
# [CV] C=4.05 ..........................................................
# [CV] ........................................... C=4.05, total=   0.6s
# [CV] ........................................... C=4.05, total=   0.6s
# [CV] C=4.05 ..........................................................
# [CV] C=4.05 ..........................................................
# [CV] ............................................ C=4.0, total=   1.0s
# [CV] C=4.1 ...........................................................
# [CV] ........................................... C=4.05, total=   0.7s
# [CV] C=4.1 ...........................................................
# [CV] ........................................... C=4.05, total=   0.5s
# [CV] C=4.1 ...........................................................
# [CV] ........................................... C=4.05, total=   0.7s
# [CV] C=4.1 ...........................................................
# [CV] ............................................ C=4.1, total=   0.7s
# [CV] C=4.1 ...........................................................
# [CV] ............................................ C=4.1, total=   0.6s
# [CV] ............................................ C=4.1, total=   0.5s
# [CV] C=4.15 ..........................................................
# [CV] C=4.15 ..........................................................
# [CV] ............................................ C=4.1, total=   0.8s
# [CV] C=4.15 ..........................................................
# [CV] ........................................... C=4.15, total=   0.5s
# [CV] C=4.15 ..........................................................
# [CV] ............................................ C=4.1, total=   0.7s
# [CV] C=4.15 ..........................................................
# [CV] ........................................... C=4.15, total=   0.7s
# [CV] C=4.2 ...........................................................
# [CV] ........................................... C=4.15, total=   0.6s
# [CV] C=4.2 ...........................................................
# [CV] ........................................... C=4.15, total=   0.6s
# [CV] ............................................ C=4.2, total=   0.4s
# [CV] C=4.2 ...........................................................
# [CV] C=4.2 ...........................................................
# [CV] ............................................ C=4.2, total=   0.7s
# [CV] C=4.2 ...........................................................
# [CV] ........................................... C=4.15, total=   0.8s
# [CV] C=4.25 ..........................................................
# [CV] ............................................ C=4.2, total=   0.6s
# [CV] C=4.25 ..........................................................
# [CV] ............................................ C=4.2, total=   0.6s
# [CV] C=4.25 ..........................................................
# [CV] ............................................ C=4.2, total=   0.7s
# [CV] C=4.25 ..........................................................
# [CV] ........................................... C=4.25, total=   0.5s
# [CV] C=4.25 ..........................................................
# [CV] ........................................... C=4.25, total=   0.7s
# [CV] ........................................... C=4.25, total=   0.9s
# [CV] C=4.3 ...........................................................
# [CV] C=4.3 ...........................................................
# [CV] ........................................... C=4.25, total=   0.6s
# [CV] C=4.3 ...........................................................
# [CV] ........................................... C=4.25, total=   0.6s
# [CV] C=4.3 ...........................................................
# [CV] ............................................ C=4.3, total=   0.7s
# [CV] C=4.3 ...........................................................
# [CV] ............................................ C=4.3, total=   0.8s
# [CV] C=4.35 ..........................................................
# [CV] ............................................ C=4.3, total=   0.8s
# [CV] C=4.35 ..........................................................
# [CV] ............................................ C=4.3, total=   0.5s
# [CV] C=4.35 ..........................................................
# [CV] ............................................ C=4.3, total=   0.7s
# [CV] C=4.35 ..........................................................
# [CV] ........................................... C=4.35, total=   0.6s
# [CV] C=4.35 ..........................................................
# [CV] ........................................... C=4.35, total=   0.8s
# [CV] C=4.4 ...........................................................
# [CV] ........................................... C=4.35, total=   0.5s
# [CV] C=4.4 ...........................................................
# [CV] ........................................... C=4.35, total=   0.5s
# [CV] C=4.4 ...........................................................
# [CV] ............................................ C=4.4, total=   0.5s
# [CV] C=4.4 ...........................................................
# [CV] ........................................... C=4.35, total=   0.8s
# [CV] C=4.4 ...........................................................
# [CV] ............................................ C=4.4, total=   0.8s
# [CV] C=4.45 ..........................................................
# [CV] ............................................ C=4.4, total=   0.6s
# [CV] C=4.45 ..........................................................
# [CV] ............................................ C=4.4, total=   0.7s
# [CV] C=4.45 ..........................................................
# [CV] ........................................... C=4.45, total=   0.7s
# [CV] C=4.45 ..........................................................
# [CV] ........................................... C=4.45, total=   0.6s
# [CV] C=4.45 ..........................................................
# [CV] ........................................... C=4.45, total=   1.2s
# [CV] C=4.5 ...........................................................
# [CV] ........................................... C=4.45, total=   1.0s
# [CV] ............................................ C=4.4, total=   1.6s
# [CV] C=4.5 ...........................................................
# [CV] C=4.5 ...........................................................
# [CV] ........................................... C=4.45, total=   0.9s
# [CV] C=4.5 ...........................................................
# [CV] ............................................ C=4.5, total=   0.8s
# [CV] C=4.5 ...........................................................
# [CV] ............................................ C=4.5, total=   1.1s
# [CV] C=4.55 ..........................................................
# [CV] ............................................ C=4.5, total=   1.1s
# [CV] C=4.55 ..........................................................
# [CV] ............................................ C=4.5, total=   0.6s
# [CV] C=4.55 ..........................................................
# [CV] ............................................ C=4.5, total=   1.0s
# [CV] C=4.55 ..........................................................
# [CV] ........................................... C=4.55, total=   1.0s
# [CV] C=4.55 ..........................................................
# [CV] ........................................... C=4.55, total=   1.1s
# [CV] C=4.6 ...........................................................
# [CV] ........................................... C=4.55, total=   1.0s
# [CV] C=4.6 ...........................................................
# [CV] ........................................... C=4.55, total=   0.7s
# [CV] C=4.6 ...........................................................
# [CV] ........................................... C=4.55, total=   0.7s
# [CV] C=4.6 ...........................................................
# [CV] ............................................ C=4.6, total=   0.8s
# [CV] C=4.6 ...........................................................
# [CV] ............................................ C=4.6, total=   0.7s
# [CV] C=4.65 ..........................................................
# [CV] ............................................ C=4.6, total=   0.9s
# [CV] C=4.65 ..........................................................
# [CV] ............................................ C=4.6, total=   0.6s
# [CV] C=4.65 ..........................................................
# [CV] ............................................ C=4.6, total=   0.7s
# [CV] C=4.65 ..........................................................
# [CV] ........................................... C=4.65, total=   0.9s
# [CV] C=4.65 ..........................................................
# [CV] ........................................... C=4.65, total=   0.5s
# [CV] C=4.7 ...........................................................
# [CV] ........................................... C=4.65, total=   0.8s
# [CV] C=4.7 ...........................................................
# [CV] ........................................... C=4.65, total=   0.9s
# [CV] C=4.7 ...........................................................
# [CV] ........................................... C=4.65, total=   0.6s
# [CV] C=4.7 ...........................................................
# [CV] ............................................ C=4.7, total=   0.5s
# [CV] C=4.7 ...........................................................
# [CV] ............................................ C=4.7, total=   0.6s
# [CV] C=4.75 ..........................................................
# [CV] ............................................ C=4.7, total=   0.7s
# [CV] C=4.75 ..........................................................
# [CV] ............................................ C=4.7, total=   0.5s
# [CV] C=4.75 ..........................................................
# [CV] ............................................ C=4.7, total=   0.6s
# [CV] C=4.75 ..........................................................
# [CV] ........................................... C=4.75, total=   0.6s
# [CV] C=4.75 ..........................................................
# [CV] ........................................... C=4.75, total=   0.6s
# [CV] C=4.8 ...........................................................
# [CV] ........................................... C=4.75, total=   0.7s
# [CV] C=4.8 ...........................................................
# [CV] ........................................... C=4.75, total=   0.5s
# [CV] C=4.8 ...........................................................
# [CV] ............................................ C=4.8, total=   0.4s
# [CV] C=4.8 ...........................................................
# [CV] ............................................ C=4.8, total=   0.5s
# [CV] C=4.8 ...........................................................
# [CV] ........................................... C=4.75, total=   0.6s
# [CV] C=4.85 ..........................................................
# [CV] ............................................ C=4.8, total=   0.6s
# [CV] C=4.85 ..........................................................
# [CV] ............................................ C=4.8, total=   0.6s
# [CV] C=4.85 ..........................................................
# [CV] ........................................... C=4.85, total=   0.7s
# [CV] C=4.85 ..........................................................
# [CV] ............................................ C=4.8, total=   0.8s
# [CV] C=4.85 ..........................................................
# [CV] ........................................... C=4.85, total=   0.7s
# [CV] C=4.9 ...........................................................
# [CV] ........................................... C=4.85, total=   0.7s
# [CV] C=4.9 ...........................................................
# [CV] ........................................... C=4.85, total=   0.6s
# [CV] C=4.9 ...........................................................
# [CV] ........................................... C=4.85, total=   0.9s
# [CV] C=4.9 ...........................................................
# [CV] ............................................ C=4.9, total=   0.8s
# [CV] C=4.9 ...........................................................
# [CV] ............................................ C=4.9, total=   0.9s
# [CV] C=4.95 ..........................................................
# [CV] ............................................ C=4.9, total=   0.9s
# [CV] C=4.95 ..........................................................
# [CV] ............................................ C=4.9, total=   0.8s
# [CV] C=4.95 ..........................................................
# [CV] ............................................ C=4.9, total=   0.9s
# [CV] C=4.95 ..........................................................
# [CV] ........................................... C=4.95, total=   0.7s
# [CV] C=4.95 ..........................................................
# [CV] ........................................... C=4.95, total=   0.6s
# [CV] ........................................... C=4.95, total=   0.3s
# [CV] ........................................... C=4.95, total=   0.5s
# [CV] ........................................... C=4.95, total=   0.3s
# [Parallel(n_jobs=-1)]: Done 495 out of 495 | elapsed:  1.0min finished
# /home/pace/Documents/data_science/project-pace-mourad/adrian/src/plots.py:30: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if train_scores_std != None and val_scores_std != None:
# Best ['C'] = {'C': 0.80000000000000004} with score : 0.7255
# Execution time : 62.313812494277954 seconds
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': array([ 0.05,  0.1 , ...,  4.9 ,  4.95])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=2)

# %% [markdown]
# all fetures 5000 Best ['C'] = {'C': 0.80000000000000004} with score : 0.7255

# %% [markdown]
# only words 5000 Best ['C'] = {'C': 1.1000000000000001} with score : 0.72475
# Execution time : 23.30917000770569 seconds

# %%
from sklearn.model_selection import cross_val_score


start= time.time()
log_reg=LogisticRegression(C=0.8)
print("Mean CV valdiation score:",np.mean(cross_val_score(
    log_reg,X_train,y_train,scoring='accuracy',cv=5,verbose=2,n_jobs=-1)))
end=time.time()
print("Execution time : {} seconds".format(end-start))
# Out:
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV]  ................................................................
# [CV] ................................................. , total=   0.2s
# [CV]  ................................................................
# [CV] ................................................. , total=   0.2s
# [CV] ................................................. , total=   0.3s
# [CV] ................................................. , total=   0.3s
# [CV] ................................................. , total=   0.2s
# Mean CV valdiation score: 0.710742448816
# Execution time : 0.7539510726928711 seconds
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.4s finished

# %% [markdown]
# only words 5000 0.723753088677

# %% [markdown]
# all features 5000 0.725500591017
